# %%
##스타트업 파일

from scipy.stats import norm
import numpy as np
import scipy as sp
from pandas.core import datetools 
import pandas as pd
import statsmodels.api as sm ## R 패키지에서 불러온것, 샘플데이터 옮겨쓸수 있는 프로젝트 있음. 회귀분석에 유용 
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import sklearn as sk 
## 전처리 

import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pylab 
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_color_codes()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.

# %% [raw]
# Machine Learing Roadmap (pseudo-code -algorithm)
#
# 1.EDA (Exploratory data analysis) -feature 설명, Background 설명
#
# 2.데이터 전처리
#    결측데이터 삭제 or Imputation
#        Scikit Learn Estimater: Imputer
#    분류 레이블 인코딩
#        Scikit Learn: LabelEncoder, one-hot-encoder 함수 사용
#
# 3.샘플링(스케일링할때 pipeline.fit설정 후 테스트 데이터 사용할시 pipeline.predict 사용)
#    Train + Test 분활
#        train_test_split 함수 사용(선택필요)
#
#    Feature scaling
#        정규화 (0과1의 범위로 스케일링) ## 실수값의 경우
#            MinMaxScaler
#        표준화 (평균0, 표준편차1: 실용적)
#            StandardScaler
#
#    Feature selection
#        정규화
#            Lasso 회귀모형(최적의 하이퍼 모수 찾기)
#        Feature 중요도 평가
#            RandomForestClassifier 의 feature_importances 속성
#
#    차원축소를 이용한 데이터 압축
#        주성분분석(PCA)
#        선형분리분석(LDA)
#        비선형 차원축소(rbf_kernel_pca)
#
#
# 4.학습알고리즘 선택
#    모델선택
#        최적화 알고리즘
#            Gradient Descent
#        머신러닝 알고리즘 (변수에 따른 선택필요)
#            의사결정나무 (No feature scaling required)
#            Random Forest (No feature scaling required)
#            QDA& LDA(독립변수 X가 정규분포를 이룰때만)
#            나이브 베이지안(다항변수)
#            K Nearest Neighbor
#            Perceptron
#            Kernel Support Vector Machine
#            신경망(Neural Network)
#        다중클래스 분류(타겟변수가 여러개의 클래스로 나뉜경우)
#            OvO
#            OvR
#
# 5.교차검증 모델성능평가 (Hyper Parameter찾기)
#        holdout 교차검증
#            train data(모델피팅),검증데이터(모델선택),test데이터로 나눔- 그후 튜닝파라미터(Hyper Parameter) 찾기
#        충화 k-fold 교차검증
#            K개로 train데이터 나눔, K-1개 Train Data(모델피팅), test data1개(모델성능추정치확인), K번반복
#        cross_val_score로 검증 스코어 평가
#        검증곡선을 이용한 평가
#        중첩 교차검증으로 알고리즘 선택하기
#
#    성능 metric
#        Confusion Matrix
#        Classification Report(Precision, Recall Rate, Fallout, F-Score)
#        ROC 커브, AUC 계산
#
#
# 6.최종모델 선택 & 평가 (최적 Hyper Parameter 성능향상) - 케글 최종성능평가 기준: log loss
# 7.예측: new 데이터 입력 & 평가

# %% [markdown]
# ## EDA(Exploratory Data Analysis)

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
train.tail() ## 26729 rows * 10 features
# Out:
#       AnimalID  Name          DateTime OutcomeType OutcomeSubtype AnimalType  \
# 26724  A702446   NaN  2015-05-14 11:56    Transfer        Partner        Cat
# 26725  A718934   NaN  2016-01-20 18:59    Transfer           SCRP        Cat
# 26726  A698128  Zeus  2015-03-09 13:33    Adoption            NaN        Dog
# 26727  A677478   NaN  2014-04-27 12:22    Transfer        Partner        Cat
# 26728  A706629   NaN   2015-07-02 9:00    Transfer           SCRP        Cat
#
#       SexuponOutcome AgeuponOutcome                    Breed  \
# 26724    Intact Male        1 month   Domestic Shorthair Mix
# 26725  Spayed Female       3 months   Domestic Shorthair Mix
# 26726  Neutered Male        4 years  Old English Bulldog Mix
# 26727    Intact Male        4 weeks   Domestic Shorthair Mix
# 26728    Intact Male         1 year   Domestic Shorthair Mix
#
#                    Color
# 26724  Brown Tabby/White
# 26725        Brown Tabby
# 26726          White/Tan
# 26727              Black
# 26728  Brown Tabby/White

# %%
train.describe() ## feature 별로 분류된 outcome 다름
# Out:
#        AnimalID   Name         DateTime OutcomeType OutcomeSubtype AnimalType  \
# count     26729  19038            26729       26729          13117      26729
# unique    26729   6374            22918           5             16          2
# top     A696288    Max  2015-08-11 0:00    Adoption        Partner        Dog
# freq          1    136               19       10769           7816      15595
#
#        SexuponOutcome AgeuponOutcome                   Breed        Color
# count           26728          26711                   26729        26729
# unique              5             44                    1380          366
# top     Neutered Male         1 year  Domestic Shorthair Mix  Black/White
# freq             9779           3969                    8810         2824

# %%
train.groupby("AnimalType").count() ## Cats = 11134, Dogs = 15595
# Out:
#             AnimalID   Name  DateTime  OutcomeType  OutcomeSubtype  \
# AnimalType
# Cat            11134   6115     11134        11134            7511
# Dog            15595  12923     15595        15595            5606
#
#             SexuponOutcome  AgeuponOutcome  Breed  Color
# AnimalType
# Cat                  11134           11117  11134  11134
# Dog                  15594           15594  15595  15595

# %%
sns.countplot(train.AnimalType, palette='Set3')
train.groupby('AnimalType').size()
# Out:
# AnimalType
# Cat    11134
# Dog    15595
# dtype: int64

# %%
sns.countplot(train.OutcomeType, palette='Set3')
train.groupby("OutcomeType").count()['AnimalID']
# Out:
# OutcomeType
# Adoption           10769
# Died                 197
# Euthanasia          1555
# Return_to_owner     4786
# Transfer            9422
# Name: AnimalID, dtype: int64

# %%
sns.countplot(train.SexuponOutcome, palette='Set3')
train.groupby('SexuponOutcome').size().sort_values(ascending = False)
# Out:
# SexuponOutcome
# Neutered Male    9779
# Spayed Female    8820
# Intact Male      3525
# Intact Female    3511
# Unknown          1093
# dtype: int64

# %%
def sex(x):
    x = str(x)
    if x.find("Male") >=0: return 'Male'
    if x.find("Female") >=0 : return 'Female'
    return 'Female' ## Imputing: Nan값: 겉으로 중성화가 되었는지 확인이 불가능한 경우는 Female
def neutered(x):
    x = str(x)
    if x.find('Spayed')>=0: return 'Neutered'
    if x.find('Neutered')>=0: return 'Neutered'
    if x.find('Intact')>=0: return'Intact'
    return 'Intact' ## imputing: 겉으로 중성화가 되었는지 확인이 불가능한 경우는 Intact Female

# %%
train['Sex'] = train.SexuponOutcome.apply(sex)
train['Neutered'] = train.SexuponOutcome.apply(neutered)

# %%
sns.countplot(data = train, y = 'Neutered', hue = 'OutcomeType') ## 중성화 수술 하면 Adoption, Return to Owener의 경우가 늘어남

# %%
sns.countplot(data = train, y = 'Sex', hue = 'OutcomeType') ## 별다른 차이 없음

# %%
f,(ax1,ax2) = plt.subplots(1,2, figsize=(20,5))
sns.countplot(train.Sex,ax =ax1)
sns.countplot(train.Neutered,ax =ax2)
print(train.groupby('Sex').size())
train.groupby('Neutered').size()
# Out:
# Sex
# Female    13425
# Male      13304
# dtype: int64
# Neutered
# Intact       8130
# Neutered    18599
# dtype: int64

# %%
f,(ax1) = plt.subplots(1,figsize=(20,5))
sns.countplot(data=train, x ='OutcomeType',hue='Sex',ax=ax1)

# %%
f,(ax1) = plt.subplots(1,figsize=(20,5))
sns.countplot(data=train, x ='AnimalType',hue='Sex',ax=ax1)

# %% [markdown]
# ## NAN 값 확인후 Imputing

# %%
## Nan 값 확인 
train.isnull().any()
# Out:
# AnimalID          False
# Name               True
# DateTime          False
# OutcomeType       False
# OutcomeSubtype     True
# AnimalType        False
# SexuponOutcome     True
# AgeuponOutcome     True
# Breed             False
# Color             False
# Sex               False
# Neutered          False
# dtype: bool

# %%
np.where(train['SexuponOutcome'].isnull()) ## 3174번 샘플 Nan값 확인
# Out:
# (array([3174], dtype=int64),)

# %%
## Imputer 
def Seximputer(x):
    x = str(x)
    if x.lower() == 'nan': return 'Neutered Male'
    else: return x

# %%
train['SexuponOutcome'] = train['SexuponOutcome'].apply(Seximputer)

# %%
np.where(train['AgeuponOutcome'].isnull())
# Out:
# (array([ 2480,  2912,  3766,  3875,  4498,  5137,  5691,  7005,  8420,
#         17464, 18490, 19927, 21523, 22380, 22448, 24328, 26551, 26570], dtype=int64),)

# %%
def Ageimputer(x):
    x = str(x)
    if x.lower() == 'nan': return '2 years' #int(np.mean(train['AgeInYears']))
    else: return x

# %%
train['AgeuponOutcome'] = train['AgeuponOutcome'].apply(Ageimputer)
np.where(train['AgeuponOutcome'].isnull())
# Out:
# (array([], dtype=int64),)

# %%
train.loc[22911]
# Out:
# AnimalID                         A710575
# Name                                 NaN
# DateTime                2015-08-24 18:56
# OutcomeType                     Transfer
# OutcomeSubtype                   Partner
# AnimalType                           Cat
# SexuponOutcome                   Unknown
# AgeuponOutcome                   0 years
# Breed             Domestic Shorthair Mix
# Color                 Orange Tabby/White
# Sex                               Female
# Neutered                          Intact
# Name: 22911, dtype: object

# %%
def calc_age_in_years(x):
    x = str(x)
    age = int(x.split()[0])
    if x.find('year') > -1: 
        if age ==0: return 0.1 ## 0 years 로 표시 되어있는 동물들 22 마리 0.1로 변환 
        else: return age
    if x.find('month')> -1:
        if age <=6: return 0.5 ## 6개월미만 float 0.5로 변환 
        else:
            return 1
    if x.find('week')> -1: return 0.1#float('{:.1f}'.format(int(x.split()[0])/52)) ## float 0.1 로 변형 
    if x.find('day')> -1: return 0.1 #float('{:.1f}'.format(int(x.split()[0])/52)) ## float 0.1 로 변형
    else: return np.mean(x)

# %%
train['AgeInYears'] = train['AgeuponOutcome'].apply(calc_age_in_years)

# %%
np.where(train['AgeInYears']==0.0) ## 0살 샘플 확인 필요 0 years ## 대부분 Transfer, some are Euthanasia or Died
# Out:
# (array([], dtype=int64),)

# %%
sns.countplot(train.AgeInYears)

# %%
sns.countplot(data=train, x='AgeInYears',hue='OutcomeType')## 결과에 따른 나이

# %%
def calc_age_category(x):
    
    if x < 0.5: return 'baby'
    elif x < 1: return 'cubs'
    elif x < 5: return 'young adult'
    elif x < 10: return 'adult'
    return 'old'
train['AgeCategory'] = train.AgeInYears.apply(calc_age_category)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='AgeCategory', ax=ax1)## 결과에 따른 나이
sns.countplot(data=train, x='AgeCategory',hue='OutcomeType', ax=ax2)## 나이에 따른 결과

# %%
f,(ax1,ax2) = plt.subplots(1,2,figsize=(20,5))
sns.countplot(data=train, x ='OutcomeType',hue='AnimalType',ax=ax1)
sns.countplot(data=train, x='AgeCategory',hue='AnimalType', ax=ax2)## 나이에 따른 Animal Type

# %%
## 안락사의 경우 subtype 이유 
## 1. 고통, 지병
## 2. 공격적인 성향 또는 행동문제
## 3. 광견병 또는 전염병의 Medical 의 이유 

euthanasia = train[train["OutcomeType"] == "Euthanasia"] 
subtype = euthanasia["OutcomeSubtype"].value_counts()

suffering = subtype["Suffering"]
behaviour = subtype["Aggressive"] +subtype["Behavior"]
medical = subtype["Rabies Risk"] + subtype["Medical"] 



subtype_list = [suffering,behaviour,medical]
list_names = ["Suffering","Behaviour","Medical"]
ind2 = np.arange(len(subtype_list))

plt.bar(ind2,subtype_list)
plt.xticks(ind2,list_names, rotation = 90)
plt.show()

# %% [markdown]
# ## Feature Values Category 분류
#
# ### Dog Breeds 나누기

# %%
group = train.groupby(['OutcomeType','Breed'])
group.size().sort_values(ascending = False)
# Out:
# OutcomeType      Breed
# Transfer         Domestic Shorthair Mix                       4538
# Adoption         Domestic Shorthair Mix                       3273
#                  Chihuahua Shorthair Mix                       767
# Return_to_owner  Pit Bull Mix                                  598
# Adoption         Labrador Retriever Mix                        590
#                  Pit Bull Mix                                  568
# Euthanasia       Domestic Shorthair Mix                        535
# Transfer         Chihuahua Shorthair Mix                       501
#                  Pit Bull Mix                                  478
# Return_to_owner  Chihuahua Shorthair Mix                       407
# Transfer         Domestic Medium Hair Mix                      383
# Return_to_owner  Labrador Retriever Mix                        369
# Adoption         Domestic Medium Hair Mix                      357
# Return_to_owner  Domestic Shorthair Mix                        352
# Transfer         Labrador Retriever Mix                        343
# Euthanasia       Pit Bull Mix                                  257
# Adoption         German Shepherd Mix                           253
# Transfer         Domestic Longhair Mix                         205
# Adoption         Domestic Longhair Mix                         199
#                  Australian Cattle Dog Mix                     177
#                  Siamese Mix                                   173
# Return_to_owner  German Shepherd Mix                           164
# Transfer         Siamese Mix                                   154
# Adoption         Dachshund Mix                                 143
# Transfer         German Shepherd Mix                           131
# Died             Domestic Shorthair Mix                        112
# Adoption         Boxer Mix                                     107
#                  Border Collie Mix                             103
# Transfer         Dachshund Mix                                 103
# Adoption         Miniature Poodle Mix                          101
#                                                               ...
# Euthanasia       Australian Cattle Dog/Pit Bull                  1
#                  Australian Shepherd                             1
# Return_to_owner  Tonkinese Mix                                   1
# Euthanasia       Australian Shepherd/Australian Cattle Dog       1
#                  Australian Shepherd/Chow Chow                   1
# Return_to_owner  Tibetan Spaniel Mix                             1
# Euthanasia       Beauceron Mix                                   1
#                  Belgian Tervuren/German Shepherd                1
# Return_to_owner  Vizsla/Rhod Ridgeback                           1
#                  West Highland                                   1
# Euthanasia       Akita/Pit Bull                                  1
#                  Akita                                           1
# Died             Himalayan                                       1
# Return_to_owner  Wire Hair Fox Terrier                           1
# Died             Lhasa Apso Mix                                  1
#                  Maltese                                         1
#                  Manx Mix                                        1
# Return_to_owner  Whippet/Whippet                                 1
# Died             Miniature Pinscher Mix                          1
#                  Pembroke Welsh Corgi/Brittany                   1
# Return_to_owner  Whippet/Labrador Retriever                      1
#                  West Highland/Chihuahua Shorthair               1
# Died             Pit Bull/Pit Bull                               1
#                  Pug/Chihuahua Shorthair                         1
#                  Rat Terrier Mix                                 1
# Return_to_owner  West Highland/Cairn Terrier                     1
# Died             Snowshoe Mix                                    1
#                  Staffordshire Mix                               1
#                  Standard Schnauzer                              1
# Transfer         Yorkshire Terrier/Rat Terrier                   1
# Length: 2415, dtype: int64

# %%
## Animal Type = Dog 인것중에 개 Breed 로 나눠 인덱싱, 총 15595 rows 
feature = 'Breed'

feature_values_dog = train.loc[train['AnimalType'] == 'Dog',feature]
group = train.groupby([feature_values_dog])
group.size().sort_values(ascending = False)
# Out:
# Breed
# Pit Bull Mix                              1906
# Chihuahua Shorthair Mix                   1766
# Labrador Retriever Mix                    1363
# German Shepherd Mix                        575
# Australian Cattle Dog Mix                  367
# Dachshund Mix                              318
# Boxer Mix                                  245
# Miniature Poodle Mix                       233
# Border Collie Mix                          229
# Australian Shepherd Mix                    163
# Rat Terrier Mix                            157
# Catahoula Mix                              157
# Jack Russell Terrier Mix                   146
# Yorkshire Terrier Mix                      143
# Chihuahua Longhair Mix                     142
# Siberian Husky Mix                         138
# Miniature Schnauzer Mix                    136
# Beagle Mix                                 124
# Rottweiler Mix                             113
# American Bulldog Mix                       109
# Cairn Terrier Mix                          102
# Shih Tzu Mix                               100
# Chihuahua Shorthair/Dachshund               98
# Australian Kelpie Mix                       95
# Staffordshire Mix                           94
# Pointer Mix                                 93
# American Staffordshire Terrier Mix          92
# Great Pyrenees Mix                          86
# Chihuahua Shorthair                         85
# Labrador Retriever/Pit Bull                 81
#                                           ...
# French Bulldog/English Bulldog               1
# Flat Coat Retriever/Labrador Retriever       1
# Golden Retriever/Finnish Spitz               1
# Golden Retriever/Pembroke Welsh Corgi        1
# Ibizan Hound/Pit Bull                        1
# Golden Retriever/Pit Bull                    1
# Hovawart Mix                                 1
# Havanese                                     1
# Harrier/Pointer                              1
# Harrier/Labrador Retriever                   1
# Greyhound/Labrador Retriever                 1
# Greyhound/Great Dane                         1
# Greyhound/Dalmatian                          1
# Great Pyrenees/Standard Poodle               1
# Great Pyrenees/Siberian Husky                1
# Great Pyrenees/Rottweiler                    1
# Great Pyrenees/Pointer                       1
# Great Pyrenees/Pit Bull                      1
# Great Pyrenees/German Shepherd               1
# Great Pyrenees/English Setter                1
# Great Pyrenees/Collie Rough                  1
# Great Pyrenees/Boxer                         1
# Great Pyrenees/Australian Shepherd           1
# Great Dane/Staffordshire                     1
# Great Dane/Pit Bull                          1
# Great Dane/German Shepherd                   1
# Great Dane/Boxer                             1
# Great Dane/Australian Cattle Dog             1
# Golden Retriever/Whippet                     1
# French Bulldog                               1
# Length: 1320, dtype: int64

# %%
## 206 가지의 개분류를 7type의 group으로 매치 ## 총 206가지 
breeds = ['Blue Lacy','Queensland Heeler','Rhod Ridgeback','Retriever','Chinese Sharpei','Black Mouth Cur','Catahoula','Staffordshire','Affenpinscher','Afghan Hound','Airedale Terrier','Akita','Australian Kelpie','Alaskan Malamute','English Bulldog','American Bulldog','American English Coonhound','American Eskimo Dog (Miniature)','American Eskimo Dog (Standard)','American Eskimo Dog (Toy)','American Foxhound','American Hairless Terrier','American Staffordshire Terrier','American Water Spaniel','Anatolian Shepherd Dog','Australian Cattle Dog','Australian Shepherd','Australian Terrier','Basenji','Basset Hound','Beagle','Bearded Collie','Beauceron','Bedlington Terrier','Belgian Malinois','Belgian Sheepdog','Belgian Tervuren','Bergamasco','Berger Picard','Bernese Mountain Dog','Bichon Fris_','Black and Tan Coonhound','Black Russian Terrier','Bloodhound','Bluetick Coonhound','Boerboel','Border Collie','Border Terrier','Borzoi','Boston Terrier','Bouvier des Flandres','Boxer','Boykin Spaniel','Briard','Brittany','Brussels Griffon','Bull Terrier','Bull Terrier (Miniature)','Bulldog','Bullmastiff','Cairn Terrier','Canaan Dog','Cane Corso','Cardigan Welsh Corgi','Cavalier King Charles Spaniel','Cesky Terrier','Chesapeake Bay Retriever','Chihuahua','Chinese Crested Dog','Chinese Shar Pei','Chinook','Chow Chow',"Cirneco dell'Etna",'Clumber Spaniel','Cocker Spaniel','Collie','Coton de Tulear','Curly-Coated Retriever','Dachshund','Dalmatian','Dandie Dinmont Terrier','Doberman Pinsch','Doberman Pinscher','Dogue De Bordeaux','English Cocker Spaniel','English Foxhound','English Setter','English Springer Spaniel','English Toy Spaniel','Entlebucher Mountain Dog','Field Spaniel','Finnish Lapphund','Finnish Spitz','Flat-Coated Retriever','French Bulldog','German Pinscher','German Shepherd','German Shorthaired Pointer','German Wirehaired Pointer','Giant Schnauzer','Glen of Imaal Terrier','Golden Retriever','Gordon Setter','Great Dane','Great Pyrenees','Greater Swiss Mountain Dog','Greyhound','Harrier','Havanese','Ibizan Hound','Icelandic Sheepdog','Irish Red and White Setter','Irish Setter','Irish Terrier','Irish Water Spaniel','Irish Wolfhound','Italian Greyhound','Japanese Chin','Keeshond','Kerry Blue Terrier','Komondor','Kuvasz','Labrador Retriever','Lagotto Romagnolo','Lakeland Terrier','Leonberger','Lhasa Apso','L_wchen','Maltese','Manchester Terrier','Mastiff','Miniature American Shepherd','Miniature Bull Terrier','Miniature Pinscher','Miniature Schnauzer','Neapolitan Mastiff','Newfoundland','Norfolk Terrier','Norwegian Buhund','Norwegian Elkhound','Norwegian Lundehund','Norwich Terrier','Nova Scotia Duck Tolling Retriever','Old English Sheepdog','Otterhound','Papillon','Parson Russell Terrier','Pekingese','Pembroke Welsh Corgi','Petit Basset Griffon Vend_en','Pharaoh Hound','Plott','Pointer','Polish Lowland Sheepdog','Pomeranian','Standard Poodle','Miniature Poodle','Toy Poodle','Portuguese Podengo Pequeno','Portuguese Water Dog','Pug','Puli','Pyrenean Shepherd','Rat Terrier','Redbone Coonhound','Rhodesian Ridgeback','Rottweiler','Russell Terrier','St. Bernard','Saluki','Samoyed','Schipperke','Scottish Deerhound','Scottish Terrier','Sealyham Terrier','Shetland Sheepdog','Shiba Inu','Shih Tzu','Siberian Husky','Silky Terrier','Skye Terrier','Sloughi','Smooth Fox Terrier','Soft-Coated Wheaten Terrier','Spanish Water Dog','Spinone Italiano','Staffordshire Bull Terrier','Standard Schnauzer','Sussex Spaniel','Swedish Vallhund','Tibetan Mastiff','Tibetan Spaniel','Tibetan Terrier','Toy Fox Terrier','Treeing Walker Coonhound','Vizsla','Weimaraner','Welsh Springer Spaniel','Welsh Terrier','West Highland White Terrier','Whippet','Wire Fox Terrier','Wirehaired Pointing Griffon','Wirehaired Vizsla','Xoloitzcuintli','Yorkshire Terrier']
groups = ['Herding','Herding','Hound','Sporting','Non-Sporting','Herding','Herding','Terrier','Toy','Hound','Terrier','Working','Working','Working','Non-Sporting','Non-Sporting','Hound','Non-Sporting','Non-Sporting','Toy','Hound','Terrier','Terrier','Sporting','Working','Herding','Herding','Terrier','Hound','Hound','Hound','Herding','Herding','Terrier','Herding','Herding','Herding','Herding','Herding','Working','Non-Sporting','Hound','Working','Hound','Hound','Working','Herding','Terrier','Hound','Non-Sporting','Herding','Working','Sporting','Herding','Sporting','Toy','Terrier','Terrier','Non-Sporting','Working','Terrier','Working','Working','Herding','Toy','Terrier','Sporting','Toy','Toy','Non-Sporting','Working','Non-Sporting','Hound','Sporting','Sporting','Herding','Non-Sporting','Sporting','Hound','Non-Sporting','Terrier','Working','Working','Working','Sporting','Hound','Sporting','Sporting','Toy','Herding','Sporting','Herding','Non-Sporting','Sporting','Non-Sporting','Working','Herding','Sporting','Sporting','Working','Terrier','Sporting','Sporting','Working','Working','Working','Hound','Hound','Toy','Hound','Herding','Sporting','Sporting','Terrier','Sporting','Hound','Toy','Toy','Non-Sporting','Terrier','Working','Working','Sporting','Sporting','Terrier','Working','Non-Sporting','Non-Sporting','Toy','Terrier','Working','Herding','Terrier','Toy','Terrier','Working','Working','Terrier','Herding','Hound','Non-Sporting','Terrier','Sporting','Herding','Hound','Toy','Terrier','Toy','Herding','Hound','Hound','Hound','Sporting','Herding','Toy','Non-Sporting','Non-Sporting','Toy','Hound','Working','Toy','Herding','Herding','Terrier','Hound','Hound','Working','Terrier','Working','Hound','Working','Non-Sporting','Hound','Terrier','Terrier','Herding','Non-Sporting','Toy','Working','Toy','Terrier','Hound','Terrier','Terrier','Herding','Sporting','Terrier','Working','Sporting','Herding','Working','Non-Sporting','Non-Sporting','Toy','Hound','Sporting','Sporting','Sporting','Terrier','Terrier','Hound','Terrier','Sporting','Sporting','Non-Sporting','Toy']
#breeds_group = np.array([breeds,groups]).T

df = pd.DataFrame([breeds,groups]).T ## 데이터 프레임으로 매치 시킴 

#df.groupby([1]).groups
df.groupby([1]).size()
#df[1] == 'Herding','breeds'
#feature_values_dog = train.loc[train['AnimalType'] == 'Dog',feature]

#df.sort_values(by=1)[0].values
# len(Herding+Hound+Non_Sporting+Sporting+Terrier+Toy +Working) = 206
# Out:
# 1
# Herding         32
# Hound           31
# Non-Sporting    25
# Sporting        31
# Terrier         33
# Toy             21
# Working         33
# dtype: int64

# %%
## 고양이 종류 총 60여가지, 크게 나누면 훨씬 쉬움
## 약 80프로 이상의 고양이가 5가지 이내의 카테고리 분류로 들어감 
feature_values_cat = train.loc[train['AnimalType'] == 'Cat',feature]
feature_values_cat
group = train.groupby([feature_values_cat])
group.size().sort_values(ascending = False)
# Out:
# Breed
# Domestic Shorthair Mix                     8810
# Domestic Medium Hair Mix                    839
# Domestic Longhair Mix                       520
# Siamese Mix                                 389
# Domestic Shorthair                          143
# Snowshoe Mix                                 75
# Manx Mix                                     44
# Maine Coon Mix                               44
# Domestic Medium Hair                         42
# Russian Blue Mix                             33
# Siamese                                      24
# Domestic Longhair                            23
# Himalayan Mix                                15
# Persian Mix                                  12
# Ragdoll Mix                                  11
# Siamese/Domestic Shorthair                   11
# American Shorthair Mix                        9
# Angora Mix                                    7
# Japanese Bobtail Mix                          6
# Bombay Mix                                    5
# Balinese Mix                                  5
# Tonkinese Mix                                 4
# Maine Coon                                    3
# Himalayan                                     3
# British Shorthair Mix                         3
# Pixiebob Shorthair Mix                        3
# Bengal Mix                                    3
# Domestic Longhair/Persian                     2
# Domestic Medium Hair/Siamese                  2
# Cymric Mix                                    2
# Bengal                                        2
# Turkish Van Mix                               2
# Abyssinian Mix                                2
# Sphynx                                        2
# Domestic Shorthair/Siamese                    2
# Exotic Shorthair Mix                          2
# Javanese Mix                                  2
# Snowshoe                                      2
# Siamese/Japanese Bobtail                      2
# Russian Blue                                  2
# Manx/Domestic Shorthair                       2
# Persian                                       2
# Domestic Shorthair/Manx                       1
# Cornish Rex Mix                               1
# Snowshoe/Ragdoll                              1
# Ragdoll                                       1
# British Shorthair                             1
# Burmese                                       1
# Devon Rex Mix                                 1
# Ocicat Mix                                    1
# Devon Rex                                     1
# Domestic Shorthair/Domestic Medium Hair       1
# Norwegian Forest Cat Mix                      1
# Munchkin Longhair Mix                         1
# Domestic Longhair/Rex                         1
# Domestic Longhair/Russian Blue                1
# Manx/Domestic Longhair                        1
# Manx                                          1
# Domestic Shorthair/British Shorthair          1
# Havana Brown Mix                              1
# dtype: int64

# %%
def Mix(x): ## Mix 인지 아닌지 구분 (개, 고양이 모두 포함 )
    x =str(x)
    if x.lower == 'nan'or '': return 'Unknown'
    if x.find('Mix')>-1:return 'Mix'
    elif x.find('/')>-1:return 'Mix'
    else:
        return 'Pure Breed'

# %%
train['Mix'] = train.Breed.apply(Mix) ## Mix column 만듬 (나중에 필요시 삭제)
#train['Mix']
#sns.countplot(data=train, x ='Mix')

# %%
train[['Breed','Mix']]
# Out:
#                                        Breed         Mix
# 0                      Shetland Sheepdog Mix         Mix
# 1                     Domestic Shorthair Mix         Mix
# 2                               Pit Bull Mix         Mix
# 3                     Domestic Shorthair Mix         Mix
# 4                Lhasa Apso/Miniature Poodle         Mix
# 5          Cairn Terrier/Chihuahua Shorthair         Mix
# 6                     Domestic Shorthair Mix         Mix
# 7                     Domestic Shorthair Mix         Mix
# 8              American Pit Bull Terrier Mix         Mix
# 9                              Cairn Terrier  Pure Breed
# 10                    Domestic Shorthair Mix         Mix
# 11                   Miniature Schnauzer Mix         Mix
# 12                              Pit Bull Mix         Mix
# 13                     Yorkshire Terrier Mix         Mix
# 14                        Great Pyrenees Mix         Mix
# 15                    Domestic Shorthair Mix         Mix
# 16                    Domestic Shorthair Mix         Mix
# 17                              Pit Bull Mix         Mix
# 18                                Angora Mix         Mix
# 19                   Flat Coat Retriever Mix         Mix
# 20                     Queensland Heeler Mix         Mix
# 21                    Domestic Shorthair Mix         Mix
# 22                         Plott Hound/Boxer         Mix
# 23                       German Shepherd Mix         Mix
# 24                       German Shepherd Mix         Mix
# 25                    Domestic Shorthair Mix         Mix
# 26        American Staffordshire Terrier Mix         Mix
# 27                   Chihuahua Shorthair Mix         Mix
# 28                    Domestic Shorthair Mix         Mix
# 29                          Russian Blue Mix         Mix
# ...                                      ...         ...
# 26699          American Pit Bull Terrier Mix         Mix
# 26700         Great Pyrenees/Anatol Shepherd         Mix
# 26701               Jack Russell Terrier Mix         Mix
# 26702                            Siamese Mix         Mix
# 26703                  Domestic Longhair Mix         Mix
# 26704                 Domestic Shorthair Mix         Mix
# 26705                 Domestic Shorthair Mix         Mix
# 26706                 Domestic Shorthair Mix         Mix
# 26707                 Domestic Shorthair Mix         Mix
# 26708                Chihuahua Shorthair Mix         Mix
# 26709                Chihuahua Shorthair Mix         Mix
# 26710  Chihuahua Shorthair/Yorkshire Terrier         Mix
# 26711               Cocker Spaniel/Dachshund         Mix
# 26712                            Rat Terrier  Pure Breed
# 26713                  Domestic Longhair Mix         Mix
# 26714                 Domestic Shorthair Mix         Mix
# 26715                            Pointer Mix         Mix
# 26716                       Newfoundland Mix         Mix
# 26717                        Bullmastiff Mix         Mix
# 26718         Siberian Husky/German Shepherd         Mix
# 26719                 Domestic Shorthair Mix         Mix
# 26720                 Domestic Shorthair Mix         Mix
# 26721                 Domestic Shorthair Mix         Mix
# 26722                 Domestic Shorthair Mix         Mix
# 26723                      Staffordshire Mix         Mix
# 26724                 Domestic Shorthair Mix         Mix
# 26725                 Domestic Shorthair Mix         Mix
# 26726                Old English Bulldog Mix         Mix
# 26727                 Domestic Shorthair Mix         Mix
# 26728                 Domestic Shorthair Mix         Mix
#
# [26729 rows x 2 columns]

# %%
sns.countplot(data=train, y='Mix',hue ="OutcomeType") 
## Mix의 Sample수가 훨씬많고 결과에 따른 분포가 높으나 pure breed의 경우 안락사율이 낮고 Return to owener, Adoption,Transfer의 경우가 거의 비슷하게 나옴

# %% [markdown]
# ## Dog's type 총 10 category(위키피디아 참조)

# %%
## Dog's type 총 10 category

## 목양견, 양치기견
Herding = ['Bearded Collie', 'Beauceron', 'Belgian Malinois','Malinois','Anatol','Anatol Shepherd',
       'Belgian Sheepdog', 'Belgian Tervuren', 'Bergamasco','Kelpie/Pit','Kelpie/Finnish',
       'Berger Picard', 'Shetland Sheepdog', 'Border Collie','Border Collie/Greyhound', 'Briard',
       'Pyrenean Shepherd', 'Puli', 'Polish Lowland Sheepdog','Border','Collie/Rottweiler',
       'Cardigan Welsh Corgi','Cardigan', 'Pembroke Welsh Corgi','Welsh','Corgi/Brittany','Border Collie/Rottweiler',
       'Old English Sheepdog', 'Collie', 'Norwegian Buhund','Pointer/Collie Smooth','Pointer/Collie',
       'Miniature American Shepherd', 'Entlebucher Mountain Dog','Belgian Malinois','Dutch','Dutch Shepherd'
       'Finnish Lapphund', 'Gefrman Shepherd', 'Icelandic Sheepdog','Catahoula/Pit',
       'Spanish Water Dog', 'Australian Shepherd Mix', 'Australian Shepherd','Bouvier des Flandres',
       'Queensland Heeler','Heeler', 'Swedish Vallhund','Swedish Vallhund Mix','Vallhund', 'Australian Cattle Dog',
        'Black Mouth Cur','Mouth','Catahoula', 'Anatolian Shepherd Dog',
        'Collie','Sheepdog','Corgi','Mountain','Cattle','Water Dog']
Australian_Shepherd = ['Australian Shepherd Mix','Australian Shepherd','Australian Shepherd/Anatol Shepherd']

## 사냥견
Hound = ['Greyhound','Basset', 'Hound','Saluki','Rhodesian Ridgeback','Redbone Coonhound','Treeing','Treeing Walker Coonhound',
         'Treeing Walker Coonhound Mix','Beagle/Pointer','Beagle/Staffordshire','Portuguese Podengo Pequeno','Podengo Pequeno Mix',
         'Podengo','Plott','Norwegian Elkhound','Pharaoh Hound','Petit Basset Griffon Vend_en','Pug/Beagle','Beagle/Pug',
         'Afghan Hound','Otterhound','Whippet','Borzoi','English Foxhound','Irish Wolfhound','Wolfhound','Basenji','Basset Hound',
         'Boxer/Beagle','Beagle','Beagle/Treeing','Harrier','Harrier/Catahoula','Sloughi','Ibizan Hound','American Foxhound','Foxhound',
         'Rhod Ridgeback','Rhod ','Ridgeback','Rhod/Ridgeback','Black and Tan Coonhound','Beagle/Chihuahua','Pbgv','Boxer/Harrier',
         'American English Coonhound','Coonhound','Bloodhound','Bluetick Coonhound','Scottish Deerhound','Plott Hound',
         "Cirneco dell'Etna",'Pit Bull/Dogue De Bordeaux','Carolina','De','Bordeaux','Basenji/Chihuahua']

## 실내견,가정견,애완견 Companian dogs
Non_Sporting = ['Finnish','French Bulldog','Keeshond','Dalmatian','Dalmatian/Boxer','Sharpei','Chinese Sharpei','Chinese Sharpei Mix','Coton de Tulear',
 'Lhasa Apso','Lhasa', 'Apso','Norwegian Lundehund','L_wchen','Xoloitzcuintli','Schipperke','Schipperke/Chihuahua','American Bulldog','Bulldog/Pointer',
 'English Bulldog','Bichon Fris','Bichon Frise Mix','Bichon','Bulldog','Standard Poodle','Eskimo','Tibetan Spaniel','Bulldog/Chihuahua',
 'Chinese Shar Pei','Miniature Poodle','Shiba Inu','Mexican Hairless Mix','Crested']
## 스포츠견, 활동적, 야외활동
Sporting = ['Greyhound/Dalmatian','Irish Red and White Setter','Irish Setter','Setter/Pit','Sussex Spaniel','Nova Scotia Duck Tolling Retriever','Irish Water Spaniel',
 'Labrador Retriever','Retriever/Whippet','Labrador','Lagotto Romagnolo','Vizsla','Vizsla Mix','Vizsla/Boxer','Vizsla/Staffordshire',
 'Vizsla/Rhod Ridgeback', 'Vizsla/Catahoula','Weimaraner','Pointer','Pointer/Catahoula','Catahoula/Pointer','Dachshund/Harrier','Canario',
 'Welsh Springer Spaniel','Springer', 'Spaniel','WireDachshund/Chihuahuahaired Pointing Griffon','Dachshund/Catahoula','Dachshund/German','Landseer','Jindo',
 'Wirehaired Vizsla','Spinone Italiano','Spinone','Spinone Italiano Mix','Gordon Setter','Brittany','Golden','Golden Retriever','Boykin','Boykin Span Mix','Boykin Spaniel','American Water Spaniel','American Eskimo Dog',
 'English Cocker Spaniel','English Setter','English Setter Mix','Curly-Coated Retriever','Cocker Spaniel','Cocker','English Springer Spaniel','Field Spaniel','Shiba','Inu/Dachshund',
 'Clumber Spaniel','Flat Coat','Flat','Flat Coated Retriever','Retriever','Chesapeake Bay Retriever','Chesa','Chow Chow','Chow','Bay','German Shorthaired Pointer',
 'German Wirehaired Pointer','Cocker Spaniel/Dachshund','Spaniel/Dachshund','Dachshund','Dachshund/Pit','Dachshund/Beagle',
 'Beagle/Dachshund','Dachshund/Chihuahua','Dachshund/Catahoula','Dachshund/Whippet','Wirehaired']
## 테리어견종 - 사냥견중 작은 품종( 주로 오소리, 새등을 잡는 품종으로 개량됨)
Terrier = ['Skye Terrier','Cesky Terrier','Norfolk Terrier','Dandie Dinmont Terrier','Border Terrier','Scottish Terrier','Terrier/Dachshund',
 'Norwich Terrier','Parson Russell Terrier','Miniature Schnauzer','Rat Terrier','Sealyham Terrier','Russell Terrier','Terrier/Boxer','Tibetan Terrier',
 'Bedlington Terrier','Smooth Fox Terrier','Bull Terrier (Miniature)','Staffordshire','Staffordshire/Labrador Retriever',
 'Staffordshire/French Bulldog','Staffordshire/English Bulldog','Staffordshire/Boxer','Staffordshire/Beagle','Glen of Imaal Terrier','Imaal','Wire Fox Terrier','Boston Terrier',
 'Bull Terrier','Highland','West Highland White Terrier','Irish Terrier','Welsh Terrier','Airedale Terrier','Staffordshire Bull Terrier',
 'Kerry Blue Terrier','Cairn Terrier','American Hairless Terrier','Lakeland Terrier','American Staffordshire Terrier','Australian Terrier',
 'Manchester Terrier','Soft-Coated Wheaten Terrier','Miniature Bull Terrier', 'Cairn Terrier/Chihuahua Shorthair','Terrier/Chihuahua','Cairn Terrier',
 'Jack Russell Terrier Mix','Rat Terrier','Cairn','Russell','Rat','Terrier/Border','Norwich Terrier/Pug','Terrier/Pug','Terr','Feist']
## 토이견 
Toy = ['Toy','Poodle/Maltese','Toy Poodle/Maltese','Brussels Griffon','Pomeranian','Silky Terrier','American Eskimo Dog (Toy)',
       'Toy Fox Terrier','Affenpinscher','Shih Tzu','Shih', 'Tzu','Whippet/Chihuahua Shorthair','Whippet/Chihuahua','Bruss Griffon Mix','Bruss',
        'Pug','Pug/Chihuahua','Yorkshire Terrier','Toy Poodle','Miniature Pinscher','Japanese Chin','Chinese Crested Dog','Maltese','Pekingese',
         'Italian Greyhound','English Toy Spaniel','Papillon','Chihuahua','Havanese','Cavalier King Charles Spaniel','Cavalier','Bull/Chihuahua',
         'Miniature','Poodle','Yorkshire', 'Terrier','Norfolk','West Highland/Chihuahua Shorthair','Highland/Chihuahua',
       'Papillon/Chihuahua Shorthair','Papillon/Chihuahua','Maltese/Yorkshire']
## 비지니스 활동견
Working = ['Giant Schnauzer','Australian Kelpie','Kelpie','Alaskan Malamute','Alaskan', 'Malamute',
       'Greater Swiss Mountain Dog', 'Komondor', 'Kuvasz','Blue Lacy/Beagle','Lacy/Beagle',
           'Blue Lacy','Lacy','Blue Lacy/Pit Bull','Lacy/Pit','Lacy/Collie','Boxer/Staffordshire',
       'Tibetan Mastiff', 'Great Pyrenees','Great Pyrenees Mix','Pyrenees', 'Leonberger',
       'Pinscher', 'Standard Schnauzer','Great Pyrenees/Anatol Shepherd','Pyrenees/Anatol',
       'Mastiff', 'Bullmastiff', 'Canaan','Schnauzer','Cane Corso','Corso',
        'St.','St. Bernard','St. Bernard Rough Coat Mix', 'Boxer', 'Samoyed',
       'Doberman Pinscher', 'Boerboel', 'Bernese Mountain Dog', 'Chinook','Akita Mix','Akita',
       'Siberian Husky','Husky','Siberian Husky/German Shepherd','Siberian','Husky/German', 'Newfoundland', 'Neapolitan Mastiff',
       'Doberman Pinsch','Doberman', 'Pinsch', 'Portuguese Water Dog', 'Black Russian Terrier',
       'Great Dane','Great','Dane','Dane/Staffordshire','Great Dane/Staffordshire']
Unknown = ['Unknown','Unknown Mix','Nan','nan']
## 맹견, 투사견 또는 fierce
Fierce = ['Pit','Pit Bull','Pit Bull Mix','American Pit Bull Terrier Mix','American Pit Bull Terrier','Dogo Argentino','Pit Bull/Pit Bull',
            'Pit Bull Terrier','Labrador Retriever/Pit Bull','Pit Bull/Rottweiler','Pit Bull/Chinese Sharpei','Bull/Chinese',
            'Bull/Rottweiler','Rottweiler Mix','Rottweiler','Boxer/Pit Bull','Pit Bull/Boxer','Pit Bull/St. Bernard Smooth Coat',
            'Dogo','Argentino','Dogo Argentino Mix','Dogo Argentino/Chinese Sharpei','kita/Pit Bull','Akita/Pit','Pit Bull/Weimaraner',
            'American Pit Bull Terrier/Chinese Sharpei','Pit Bull/Mastiff','Mastiff/Pit Bull','Pit Bull/Catahoula','Canaan Dog/Pit Bull',
         'American Pit Bull Terrier/Catahoula']
## Guard 견 
German_Shepherd = ['German Shepherd Mix','German Shepherd','German Shepherd/Akita','Shepherd/Australian',
                   'German Shepherd/Rottweiler','German Shepherd/Pit Bull','German Shepherd/Catahoula','Rottweiler/German Shepherd',
                   'German','Shepherd/Rottweiler','German Shepherd/Collie Rough','Beagle/German','German Shepherd/Boxer',
                   'Beagle/German Shepherd','Boxer/German Shepherd','German Shepherd/Mastiff','German Shepherd/Collie Smooth']

# %% [markdown]
# ## Cat's Type 9종류 분류 (위키피디아 참조)

# %%
## Cat's Type 9종류 분류 ( 위키피디아 기준)

## 미국토종 고양이 (미국인들 선호, 대부분의 고양이가 여기에 포함), 쥐잡이용 고양이, 활동성 큼, 건강함 , 애교많음 , 질투많음
Domestic = ['American Shorthair Mix','Domestic Shorthair Mix','Domestic Medium Hair Mix','Domestic Longhair Mix',
            'Domestic Shorthair','Domestic Medium Hair','Domestic Longhair','Domestic Shorthair/Domestic Medium Hair','Domestic Longhair/Rex']
## 브리티쉬 고양이 ( 미국 토종고양이의 조상)
British = ['British Shorthair Mix','Domestic Shorthair/British Shorthair','British Shorthair']
## 시암고양이, 우아함, 특이한 색, 흰색& 회백색 얼굴 , 질투많음, 관심 보살핌 필요
Siamese = ['Siamese Mix','Siamese','Siamese/Domestic Shorthair','Domestic Medium Hair/Siamese',
           'Domestic Shorthair/Siamese' ,'Siamese/Japanese Bobtail']
#스노우 슈: 여왕의 고양이, 온순하고 영리. 혼자 방치되는 것을 싫어함
Snowshoe =['Snowshoe','Snowshoe Mix','Snowshoe/Ragdoll']
##특이품종이지만 개채수 20마리 이상
Russian_Blue = ['Russian Blue Mix','Russian Blue','Domestic Longhair/Russian Blue']
Persian = ['Persian Mix','Persian','Domestic Longhair/Persian']
Manx = ['Manx Mix','Manx','Manx/Domestic Longhair','Manx/Domestic Shorthair','Domestic Shorthair/Manx']
Maine_Coon = ['Maine Coon Mix','Maine Coon']
## 특이 품종 20 마리 미만
Exotic = ['Abyssinian Mix','Himalayan Mix','Himalayan','Bengal Mix','Bengal','Ragdoll Mix','Angora Mix','Japanese Bobtail Mix',
          'Bombay Mix','Balinese Mix','Tonkinese Mix','Pixiebob Shorthair Mix','Cymric Mix','Turkish Van Mix',
          'Sphynx','Exotic Shorthair Mix','Javanese Mix','Cornish Rex Mix','Ragdoll','Burmese','Devon Rex Mix',
          'Ocicat Mix','Devon Rex','Norwegian Forest Cat Mix','Munchkin Longhair Mix','Havana Brown Mix']

# %%
def BreedGroups(x):
      
    x =str(x)
    if x: ## 개 3그룹으로 선분류 
        if x in Unknown:
            return 'Companion'  ##array([ 4967, 23667]) - Dogs, return to owner & Names exsist
        elif x in Fierce:
            return 'Fierce'
        elif x in German_Shepherd:
            return 'Working'
        elif x in Australian_Shepherd:
            return 'Herding'
        
        ## 고양이 그룹 분류: 9 종류 
        elif x in Domestic:
            return 'Domestic'
        elif x in British:
            return 'Exotic'
        elif x in Siamese:
            return 'Exotic'
        elif x in Snowshoe:
            return 'Exotic'
        elif x in Russian_Blue:
            return 'Exotic'
        elif x in Persian:
            return 'Exotic'
        elif x in Manx:
            return 'Exotic'
        elif x in Maine_Coon:
            return 'Exotic'
        elif x in Exotic:
            return 'Exotic'
        
## 선분류 그룹에 속하지 않는 그룹: 개 7 종류 (목적 분류 세분화 ## split 함수로 ()다시나누기필요 )       
        else: 
            x = x.split()
            for i in x: 
                if i in Herding:
                    return 'Herding'
                elif i in Hound:
                    return 'Hunting'
                elif i in Non_Sporting:
                    return 'Companion'
                elif i in Sporting:
                    return 'Sporting'
                elif i in Terrier:
                    return 'Hunting'
                elif i in Toy:
                    return 'Toy'
                elif i in Working:
                    return 'Working'
                
        return 'Sporting'

# %%
#feature_values_dog
train['BreedGroup'] = train.Breed.apply(BreedGroups)

#pd.set_option('display.max_rows',1000) 
train[['Breed','OutcomeType','BreedGroup']].iloc[7000:8000]
# Out:
#                                          Breed      OutcomeType BreedGroup
# 7000                    Labrador Retriever Mix         Adoption   Sporting
# 7001                       German Shepherd Mix         Adoption    Working
# 7002                    Domestic Shorthair Mix         Adoption   Domestic
# 7003                    Domestic Shorthair Mix         Transfer   Domestic
# 7004                       German Shepherd Mix         Transfer    Working
# 7005                    Domestic Shorthair Mix         Transfer   Domestic
# 7006                     Domestic Longhair Mix  Return_to_owner   Domestic
# 7007                    Domestic Shorthair Mix         Adoption   Domestic
# 7008                 Labrador Retriever/Beagle         Adoption   Sporting
# 7009                    Domestic Shorthair Mix         Adoption   Domestic
# 7010                        Labrador Retriever  Return_to_owner   Sporting
# 7011                  Domestic Medium Hair Mix         Transfer   Domestic
# 7012                   Chihuahua Shorthair Mix  Return_to_owner        Toy
# 7013                    Domestic Shorthair Mix         Transfer   Domestic
# 7014                    Domestic Shorthair Mix         Transfer   Domestic
# 7015                             Catahoula Mix         Transfer    Herding
# 7016                  Domestic Medium Hair Mix         Transfer   Domestic
# 7017                    Domestic Shorthair Mix         Transfer   Domestic
# 7018                    Labrador Retriever Mix         Transfer   Sporting
# 7019                              Pit Bull Mix       Euthanasia     Fierce
# 7020                                Beagle Mix         Transfer    Hunting
# 7021                    Domestic Shorthair Mix         Transfer   Domestic
# 7022                              Pit Bull Mix         Transfer     Fierce
# 7023                    Domestic Shorthair Mix             Died   Domestic
# 7024                 Catahoula/Black Mouth Cur         Transfer    Herding
# 7025                              Pit Bull Mix         Adoption     Fierce
# 7026                              Pit Bull Mix         Transfer     Fierce
# 7027                    Domestic Shorthair Mix         Transfer   Domestic
# 7028                   Chihuahua Shorthair Mix         Adoption        Toy
# 7029  Australian Cattle Dog/Labrador Retriever         Adoption    Herding
# ...                                        ...              ...        ...
# 7970                    Domestic Shorthair Mix         Adoption   Domestic
# 7971                            Pit Bull/Boxer         Adoption     Fierce
# 7972                            Rottweiler Mix         Adoption     Fierce
# 7973                    Labrador Retriever Mix         Adoption   Sporting
# 7974                 Australian Cattle Dog Mix         Transfer    Herding
# 7975                              Pit Bull Mix         Adoption     Fierce
# 7976                             Chow Chow Mix       Euthanasia   Sporting
# 7977                       Tibetan Spaniel Mix         Adoption   Sporting
# 7978                       Chihuahua Shorthair  Return_to_owner        Toy
# 7979                                  Manx Mix         Adoption     Exotic
# 7980                    Domestic Shorthair Mix         Transfer   Domestic
# 7981                        Domestic Shorthair         Transfer   Domestic
# 7982                    Domestic Shorthair Mix         Adoption   Domestic
# 7983         Labrador Retriever/Siberian Husky       Euthanasia   Sporting
# 7984                    Domestic Shorthair Mix         Transfer   Domestic
# 7985                   Chihuahua Shorthair Mix         Adoption        Toy
# 7986                      Miniature Poodle Mix         Adoption        Toy
# 7987             Rottweiler/Labrador Retriever  Return_to_owner   Sporting
# 7988                    Domestic Shorthair Mix         Transfer   Domestic
# 7989                   Chihuahua Shorthair Mix         Adoption        Toy
# 7990                    Domestic Shorthair Mix  Return_to_owner   Domestic
# 7991                              Pit Bull Mix         Transfer     Fierce
# 7992                              Pit Bull Mix         Transfer     Fierce
# 7993                        Labrador Retriever         Adoption   Sporting
# 7994                           German Shepherd  Return_to_owner    Working
# 7995                    Domestic Shorthair Mix         Adoption   Domestic
# 7996                              Pit Bull Mix         Adoption     Fierce
# 7997                              Pit Bull Mix         Adoption     Fierce
# 7998                    Domestic Shorthair Mix         Adoption   Domestic
# 7999                    Domestic Shorthair Mix         Transfer   Domestic
#
# [1000 rows x 3 columns]

# %%
sns.countplot(data =train, y='BreedGroup')

# %%
np.where(train['BreedGroup']=='Nan') ## return to owner
# Out:
# (array([], dtype=int64),)

# %%
train.groupby('BreedGroup').size()
# Out:
# BreedGroup
# Companion      401
# Domestic     10388
# Exotic         746
# Fierce        2367
# Herding       1904
# Hunting       1576
# Sporting      3459
# Toy           4097
# Working       1791
# dtype: int64

# %%
sns.countplot(data=train, y='BreedGroup',hue ="OutcomeType")

# %%
def Name(x):
    x= str(x)
    if x == 'Nan': return 'No'
    elif x =='nan': return 'No'
    elif x.lower() =='unknown': return 'No'
    else: return 'Yes'

# %%
train['NameExsist'] = train['Name'].apply(Name)
train
# Out:
#       AnimalID        Name          DateTime      OutcomeType OutcomeSubtype  \
# 0      A671945     Hambone  2014-02-12 18:22  Return_to_owner            NaN
# 1      A656520       Emily  2013-10-13 12:44       Euthanasia      Suffering
# 2      A686464      Pearce  2015-01-31 12:28         Adoption         Foster
# 3      A683430         NaN  2014-07-11 19:09         Transfer        Partner
# 4      A667013         NaN  2013-11-15 12:52         Transfer        Partner
# 5      A677334        Elsa  2014-04-25 13:04         Transfer        Partner
# 6      A699218       Jimmy  2015-03-28 13:11         Transfer        Partner
# 7      A701489         NaN  2015-04-30 17:02         Transfer        Partner
# 8      A671784        Lucy  2014-02-04 17:17         Adoption            NaN
# 9      A677747         NaN   2014-05-03 7:48         Adoption        Offsite
# 10     A668402         NaN  2013-12-05 15:50         Transfer           SCRP
# 11     A666320         NaN  2013-11-04 14:48         Adoption            NaN
# 12     A684601      Rocket  2016-02-03 11:27         Adoption         Foster
# 13     A704702     Scooter  2015-06-08 16:30  Return_to_owner            NaN
# 14     A688584     Preston  2015-11-25 15:00  Return_to_owner            NaN
# 15     A678825      Oliver  2014-07-12 12:10         Adoption         Foster
# 16     A678050         NaN  2014-05-03 16:15         Transfer        Partner
# 17     A680028         NaN  2014-06-07 12:54         Transfer        Partner
# 18     A679010     Chrissy  2014-05-17 11:32         Transfer        Partner
# 19     A684787        Kuma  2014-07-30 17:34  Return_to_owner            NaN
# 20     A670658      Anders  2014-01-19 15:03         Transfer        Partner
# 21     A708812    Munchkin  2015-09-18 15:19         Transfer        Partner
# 22     A705262     Jamaica  2015-08-15 14:22         Adoption            NaN
# 23     A665781     Quattro  2013-10-28 16:32         Adoption            NaN
# 24     A676333     Trigger  2014-04-09 17:44  Return_to_owner            NaN
# 25     A712750       Olive  2015-10-03 15:44         Transfer        Partner
# 26     A718832         Nia  2016-01-15 17:31         Adoption            NaN
# 27     A698777       Chloe  2015-03-25 18:50         Adoption            NaN
# 28     A715348     Cymbale  2015-11-21 13:01         Adoption            NaN
# 29     A708666         Jax  2015-07-30 14:30  Return_to_owner            NaN
# ...        ...         ...               ...              ...            ...
# 26699  A676460       Mario  2014-04-21 14:01       Euthanasia       Behavior
# 26700  A704999        Lion  2015-06-15 19:28  Return_to_owner            NaN
# 26701  A678842        Ella  2014-06-15 17:41         Transfer        Partner
# 26702  A713637         NaN   2015-10-11 9:42             Died      In Kennel
# 26703  A716670      Mowmow  2015-12-04 12:22         Transfer        Partner
# 26704  A716223       Alice  2015-11-17 17:17         Transfer        Partner
# 26705  A662498       Grace  2013-10-19 15:34         Transfer        Partner
# 26706  A689942        Zoey  2014-10-19 13:29         Adoption            NaN
# 26707  A682690         NaN  2014-07-01 17:06       Euthanasia      Suffering
# 26708  A666920      Herbie  2013-11-13 17:32         Transfer        Partner
# 26709  A714386         NaN   2015-10-24 0:00         Adoption            NaN
# 26710  A692622      Bonnie  2014-11-24 17:21         Transfer        Partner
# 26711  A666284       Sonja  2013-10-30 18:32         Transfer        Partner
# 26712  A535277      Merlin  2015-04-20 16:04  Return_to_owner            NaN
# 26713  A671169         NaN  2014-01-20 17:37       Euthanasia      Suffering
# 26714  A679031        Pete  2014-05-31 16:11         Adoption            NaN
# 26715  A708833        Luna  2015-08-05 17:03         Adoption            NaN
# 26716  A697158         Max  2015-05-02 21:04         Adoption        Offsite
# 26717  A519949       Bella  2014-06-30 17:34  Return_to_owner            NaN
# 26718  A701044         NaN  2015-04-28 14:26         Adoption            NaN
# 26719  A707871         NaN   2015-07-20 9:00         Transfer           SCRP
# 26720  A704405     Brownie  2015-07-18 14:08         Adoption            NaN
# 26721  A662019  Green Bean   2014-07-17 9:43         Adoption         Foster
# 26722  A687056         NaN   2014-08-31 9:00         Transfer           SCRP
# 26723  A716997        Zeus  2016-01-29 18:52         Adoption            NaN
# 26724  A702446         NaN  2015-05-14 11:56         Transfer        Partner
# 26725  A718934         NaN  2016-01-20 18:59         Transfer           SCRP
# 26726  A698128        Zeus  2015-03-09 13:33         Adoption            NaN
# 26727  A677478         NaN  2014-04-27 12:22         Transfer        Partner
# 26728  A706629         NaN   2015-07-02 9:00         Transfer           SCRP
#
#       AnimalType SexuponOutcome AgeuponOutcome  \
# 0            Dog  Neutered Male         1 year
# 1            Cat  Spayed Female         1 year
# 2            Dog  Neutered Male        2 years
# 3            Cat    Intact Male        3 weeks
# 4            Dog  Neutered Male        2 years
# 5            Dog  Intact Female        1 month
# 6            Cat    Intact Male        3 weeks
# 7            Cat        Unknown        3 weeks
# 8            Dog  Spayed Female       5 months
# 9            Dog  Spayed Female         1 year
# 10           Cat        Unknown        2 years
# 11           Dog  Spayed Female        2 years
# 12           Dog  Neutered Male        4 years
# 13           Dog  Neutered Male        2 years
# 14           Dog  Neutered Male         1 year
# 15           Cat  Neutered Male       3 months
# 16           Cat    Intact Male        3 weeks
# 17           Dog  Intact Female        2 weeks
# 18           Cat  Intact Female        2 years
# 19           Dog  Neutered Male         1 year
# 20           Dog    Intact Male       2 months
# 21           Cat  Spayed Female         1 year
# 22           Dog  Spayed Female        2 years
# 23           Dog  Neutered Male      10 months
# 24           Dog  Neutered Male       2 months
# 25           Cat  Intact Female        1 month
# 26           Dog  Spayed Female       6 months
# 27           Dog  Spayed Female        5 years
# 28           Cat  Spayed Female       2 months
# 29           Cat  Neutered Male        7 years
# ...          ...            ...            ...
# 26699        Dog  Neutered Male        2 years
# 26700        Dog    Intact Male      10 months
# 26701        Dog  Intact Female      11 months
# 26702        Cat  Spayed Female        2 years
# 26703        Cat  Neutered Male        6 years
# 26704        Cat  Intact Female        4 weeks
# 26705        Cat  Intact Female       2 months
# 26706        Cat  Spayed Female       2 months
# 26707        Cat        Unknown         1 year
# 26708        Dog  Neutered Male        2 years
# 26709        Dog  Spayed Female        1 month
# 26710        Dog  Intact Female        1 month
# 26711        Dog  Intact Female         1 year
# 26712        Dog  Neutered Male       12 years
# 26713        Cat  Intact Female       18 years
# 26714        Cat  Spayed Female       2 months
# 26715        Dog  Spayed Female       2 months
# 26716        Dog  Neutered Male       2 months
# 26717        Dog  Spayed Female        9 years
# 26718        Dog  Neutered Male       2 months
# 26719        Cat        Unknown        2 years
# 26720        Cat  Spayed Female       2 months
# 26721        Cat  Spayed Female        5 years
# 26722        Cat    Intact Male       5 months
# 26723        Dog  Neutered Male        6 years
# 26724        Cat    Intact Male        1 month
# 26725        Cat  Spayed Female       3 months
# 26726        Dog  Neutered Male        4 years
# 26727        Cat    Intact Male        4 weeks
# 26728        Cat    Intact Male         1 year
#
#                                        Breed                Color     Sex  \
# 0                      Shetland Sheepdog Mix          Brown/White    Male
# 1                     Domestic Shorthair Mix          Cream Tabby  Female
# 2                               Pit Bull Mix           Blue/White    Male
# 3                     Domestic Shorthair Mix           Blue Cream    Male
# 4                Lhasa Apso/Miniature Poodle                  Tan    Male
# 5          Cairn Terrier/Chihuahua Shorthair            Black/Tan  Female
# 6                     Domestic Shorthair Mix           Blue Tabby    Male
# 7                     Domestic Shorthair Mix          Brown Tabby  Female
# 8              American Pit Bull Terrier Mix            Red/White  Female
# 9                              Cairn Terrier                White  Female
# 10                    Domestic Shorthair Mix                Black  Female
# 11                   Miniature Schnauzer Mix               Silver  Female
# 12                              Pit Bull Mix                Brown    Male
# 13                     Yorkshire Terrier Mix            Black/Red    Male
# 14                        Great Pyrenees Mix          White/Cream    Male
# 15                    Domestic Shorthair Mix   Orange Tabby/White    Male
# 16                    Domestic Shorthair Mix          Brown Tabby    Male
# 17                              Pit Bull Mix          Brown/White  Female
# 18                                Angora Mix                White  Female
# 19                   Flat Coat Retriever Mix                Black    Male
# 20                     Queensland Heeler Mix          Black/White    Male
# 21                    Domestic Shorthair Mix                White  Female
# 22                         Plott Hound/Boxer  Brown Brindle/White  Female
# 23                       German Shepherd Mix          Brown/White    Male
# 24                       German Shepherd Mix          Black/Brown    Male
# 25                    Domestic Shorthair Mix         Orange Tabby  Female
# 26        American Staffordshire Terrier Mix      Chocolate/White  Female
# 27                   Chihuahua Shorthair Mix            White/Tan  Female
# 28                    Domestic Shorthair Mix    Cream Tabby/White  Female
# 29                          Russian Blue Mix                 Blue    Male
# ...                                      ...                  ...     ...
# 26699          American Pit Bull Terrier Mix          White/Black    Male
# 26700         Great Pyrenees/Anatol Shepherd            Tan/Cream    Male
# 26701               Jack Russell Terrier Mix          White/Black  Female
# 26702                            Siamese Mix           Lynx Point  Female
# 26703                  Domestic Longhair Mix           Seal Point    Male
# 26704                 Domestic Shorthair Mix          White/Black  Female
# 26705                 Domestic Shorthair Mix               Tortie  Female
# 26706                 Domestic Shorthair Mix                Black  Female
# 26707                 Domestic Shorthair Mix          Brown Tabby  Female
# 26708                Chihuahua Shorthair Mix          White/Brown    Male
# 26709                Chihuahua Shorthair Mix           Sable/Buff  Female
# 26710  Chihuahua Shorthair/Yorkshire Terrier          Brown/Black  Female
# 26711               Cocker Spaniel/Dachshund                 Buff  Female
# 26712                            Rat Terrier        Chocolate/Tan    Male
# 26713                  Domestic Longhair Mix               Tortie  Female
# 26714                 Domestic Shorthair Mix         Orange Tabby  Female
# 26715                            Pointer Mix          Black/White  Female
# 26716                       Newfoundland Mix          White/Black    Male
# 26717                        Bullmastiff Mix                Black  Female
# 26718         Siberian Husky/German Shepherd       Black/Tricolor    Male
# 26719                 Domestic Shorthair Mix    Brown Tabby/White  Female
# 26720                 Domestic Shorthair Mix          Brown Tabby  Female
# 26721                 Domestic Shorthair Mix                Black  Female
# 26722                 Domestic Shorthair Mix         Orange Tabby    Male
# 26723                      Staffordshire Mix           Blue/White    Male
# 26724                 Domestic Shorthair Mix    Brown Tabby/White    Male
# 26725                 Domestic Shorthair Mix          Brown Tabby  Female
# 26726                Old English Bulldog Mix            White/Tan    Male
# 26727                 Domestic Shorthair Mix                Black    Male
# 26728                 Domestic Shorthair Mix    Brown Tabby/White    Male
#
#        Neutered  AgeInYears  AgeCategory         Mix BreedGroup NameExsist
# 0      Neutered         1.0  young adult         Mix    Herding        Yes
# 1      Neutered         1.0  young adult         Mix   Domestic        Yes
# 2      Neutered         2.0  young adult         Mix     Fierce        Yes
# 3        Intact         0.1         baby         Mix   Domestic         No
# 4      Neutered         2.0  young adult         Mix  Companion         No
# 5        Intact         0.5         cubs         Mix    Hunting        Yes
# 6        Intact         0.1         baby         Mix   Domestic        Yes
# 7        Intact         0.1         baby         Mix   Domestic         No
# 8      Neutered         0.5         cubs         Mix     Fierce        Yes
# 9      Neutered         1.0  young adult  Pure Breed    Hunting         No
# 10       Intact         2.0  young adult         Mix   Domestic         No
# 11     Neutered         2.0  young adult         Mix        Toy         No
# 12     Neutered         4.0  young adult         Mix     Fierce        Yes
# 13     Neutered         2.0  young adult         Mix        Toy        Yes
# 14     Neutered         1.0  young adult         Mix    Working        Yes
# 15     Neutered         0.5         cubs         Mix   Domestic        Yes
# 16       Intact         0.1         baby         Mix   Domestic         No
# 17       Intact         0.1         baby         Mix     Fierce         No
# 18       Intact         2.0  young adult         Mix     Exotic        Yes
# 19     Neutered         1.0  young adult         Mix   Sporting        Yes
# 20       Intact         0.5         cubs         Mix    Herding        Yes
# 21     Neutered         1.0  young adult         Mix   Domestic        Yes
# 22     Neutered         2.0  young adult         Mix    Hunting        Yes
# 23     Neutered         1.0  young adult         Mix    Working        Yes
# 24     Neutered         0.5         cubs         Mix    Working        Yes
# 25       Intact         0.5         cubs         Mix   Domestic        Yes
# 26     Neutered         0.5         cubs         Mix    Hunting        Yes
# 27     Neutered         5.0        adult         Mix        Toy        Yes
# 28     Neutered         0.5         cubs         Mix   Domestic        Yes
# 29     Neutered         7.0        adult         Mix     Exotic        Yes
# ...         ...         ...          ...         ...        ...        ...
# 26699  Neutered         2.0  young adult         Mix     Fierce        Yes
# 26700    Intact         1.0  young adult         Mix    Working        Yes
# 26701    Intact         1.0  young adult         Mix    Hunting        Yes
# 26702  Neutered         2.0  young adult         Mix     Exotic         No
# 26703  Neutered         6.0        adult         Mix   Domestic        Yes
# 26704    Intact         0.1         baby         Mix   Domestic        Yes
# 26705    Intact         0.5         cubs         Mix   Domestic        Yes
# 26706  Neutered         0.5         cubs         Mix   Domestic        Yes
# 26707    Intact         1.0  young adult         Mix   Domestic         No
# 26708  Neutered         2.0  young adult         Mix        Toy        Yes
# 26709  Neutered         0.5         cubs         Mix        Toy         No
# 26710    Intact         0.5         cubs         Mix        Toy        Yes
# 26711    Intact         1.0  young adult         Mix   Sporting        Yes
# 26712  Neutered        12.0          old  Pure Breed    Hunting        Yes
# 26713    Intact        18.0          old         Mix   Domestic         No
# 26714  Neutered         0.5         cubs         Mix   Domestic        Yes
# 26715  Neutered         0.5         cubs         Mix   Sporting        Yes
# 26716  Neutered         0.5         cubs         Mix    Working        Yes
# 26717  Neutered         9.0        adult         Mix    Working        Yes
# 26718  Neutered         0.5         cubs         Mix    Working         No
# 26719    Intact         2.0  young adult         Mix   Domestic         No
# 26720  Neutered         0.5         cubs         Mix   Domestic        Yes
# 26721  Neutered         5.0        adult         Mix   Domestic        Yes
# 26722    Intact         0.5         cubs         Mix   Domestic         No
# 26723  Neutered         6.0        adult         Mix    Hunting        Yes
# 26724    Intact         0.5         cubs         Mix   Domestic         No
# 26725  Neutered         0.5         cubs         Mix   Domestic         No
# 26726  Neutered         4.0  young adult         Mix  Companion        Yes
# 26727    Intact         0.1         baby         Mix   Domestic         No
# 26728    Intact         1.0  young adult         Mix   Domestic         No
#
# [26729 rows x 17 columns]

# %%
sns.countplot(data=train, y='NameExsist',hue ="OutcomeType") ## 이름이 있는 경우 Return to Owner, Adoption의 경우가 훨씬 높음

# %% [markdown]
# ## Encoding : Label Encoding

# %% [markdown]
# ### Name : 이름이 있으면1, 없으면 0으로 변환
# ### AnimalType: Dog이면 1, Cat 이면 0로 변환
# ### Sex: Male 이면 0, Female이면 1
# ### Neutered: 중성화 되어있으면 1, 안되어있으면 0
# ### BreedGroup 종류에 따라 인코딩 필요
# ### Mix: Pure Breed 면 1, Mix 면 0

# %%
dfX= train.copy()
dfX
# Out:
#       AnimalID        Name          DateTime      OutcomeType OutcomeSubtype  \
# 0      A671945     Hambone  2014-02-12 18:22  Return_to_owner            NaN
# 1      A656520       Emily  2013-10-13 12:44       Euthanasia      Suffering
# 2      A686464      Pearce  2015-01-31 12:28         Adoption         Foster
# 3      A683430         NaN  2014-07-11 19:09         Transfer        Partner
# 4      A667013         NaN  2013-11-15 12:52         Transfer        Partner
# 5      A677334        Elsa  2014-04-25 13:04         Transfer        Partner
# 6      A699218       Jimmy  2015-03-28 13:11         Transfer        Partner
# 7      A701489         NaN  2015-04-30 17:02         Transfer        Partner
# 8      A671784        Lucy  2014-02-04 17:17         Adoption            NaN
# 9      A677747         NaN   2014-05-03 7:48         Adoption        Offsite
# 10     A668402         NaN  2013-12-05 15:50         Transfer           SCRP
# 11     A666320         NaN  2013-11-04 14:48         Adoption            NaN
# 12     A684601      Rocket  2016-02-03 11:27         Adoption         Foster
# 13     A704702     Scooter  2015-06-08 16:30  Return_to_owner            NaN
# 14     A688584     Preston  2015-11-25 15:00  Return_to_owner            NaN
# 15     A678825      Oliver  2014-07-12 12:10         Adoption         Foster
# 16     A678050         NaN  2014-05-03 16:15         Transfer        Partner
# 17     A680028         NaN  2014-06-07 12:54         Transfer        Partner
# 18     A679010     Chrissy  2014-05-17 11:32         Transfer        Partner
# 19     A684787        Kuma  2014-07-30 17:34  Return_to_owner            NaN
# 20     A670658      Anders  2014-01-19 15:03         Transfer        Partner
# 21     A708812    Munchkin  2015-09-18 15:19         Transfer        Partner
# 22     A705262     Jamaica  2015-08-15 14:22         Adoption            NaN
# 23     A665781     Quattro  2013-10-28 16:32         Adoption            NaN
# 24     A676333     Trigger  2014-04-09 17:44  Return_to_owner            NaN
# 25     A712750       Olive  2015-10-03 15:44         Transfer        Partner
# 26     A718832         Nia  2016-01-15 17:31         Adoption            NaN
# 27     A698777       Chloe  2015-03-25 18:50         Adoption            NaN
# 28     A715348     Cymbale  2015-11-21 13:01         Adoption            NaN
# 29     A708666         Jax  2015-07-30 14:30  Return_to_owner            NaN
# ...        ...         ...               ...              ...            ...
# 26699  A676460       Mario  2014-04-21 14:01       Euthanasia       Behavior
# 26700  A704999        Lion  2015-06-15 19:28  Return_to_owner            NaN
# 26701  A678842        Ella  2014-06-15 17:41         Transfer        Partner
# 26702  A713637         NaN   2015-10-11 9:42             Died      In Kennel
# 26703  A716670      Mowmow  2015-12-04 12:22         Transfer        Partner
# 26704  A716223       Alice  2015-11-17 17:17         Transfer        Partner
# 26705  A662498       Grace  2013-10-19 15:34         Transfer        Partner
# 26706  A689942        Zoey  2014-10-19 13:29         Adoption            NaN
# 26707  A682690         NaN  2014-07-01 17:06       Euthanasia      Suffering
# 26708  A666920      Herbie  2013-11-13 17:32         Transfer        Partner
# 26709  A714386         NaN   2015-10-24 0:00         Adoption            NaN
# 26710  A692622      Bonnie  2014-11-24 17:21         Transfer        Partner
# 26711  A666284       Sonja  2013-10-30 18:32         Transfer        Partner
# 26712  A535277      Merlin  2015-04-20 16:04  Return_to_owner            NaN
# 26713  A671169         NaN  2014-01-20 17:37       Euthanasia      Suffering
# 26714  A679031        Pete  2014-05-31 16:11         Adoption            NaN
# 26715  A708833        Luna  2015-08-05 17:03         Adoption            NaN
# 26716  A697158         Max  2015-05-02 21:04         Adoption        Offsite
# 26717  A519949       Bella  2014-06-30 17:34  Return_to_owner            NaN
# 26718  A701044         NaN  2015-04-28 14:26         Adoption            NaN
# 26719  A707871         NaN   2015-07-20 9:00         Transfer           SCRP
# 26720  A704405     Brownie  2015-07-18 14:08         Adoption            NaN
# 26721  A662019  Green Bean   2014-07-17 9:43         Adoption         Foster
# 26722  A687056         NaN   2014-08-31 9:00         Transfer           SCRP
# 26723  A716997        Zeus  2016-01-29 18:52         Adoption            NaN
# 26724  A702446         NaN  2015-05-14 11:56         Transfer        Partner
# 26725  A718934         NaN  2016-01-20 18:59         Transfer           SCRP
# 26726  A698128        Zeus  2015-03-09 13:33         Adoption            NaN
# 26727  A677478         NaN  2014-04-27 12:22         Transfer        Partner
# 26728  A706629         NaN   2015-07-02 9:00         Transfer           SCRP
#
#       AnimalType SexuponOutcome AgeuponOutcome  \
# 0            Dog  Neutered Male         1 year
# 1            Cat  Spayed Female         1 year
# 2            Dog  Neutered Male        2 years
# 3            Cat    Intact Male        3 weeks
# 4            Dog  Neutered Male        2 years
# 5            Dog  Intact Female        1 month
# 6            Cat    Intact Male        3 weeks
# 7            Cat        Unknown        3 weeks
# 8            Dog  Spayed Female       5 months
# 9            Dog  Spayed Female         1 year
# 10           Cat        Unknown        2 years
# 11           Dog  Spayed Female        2 years
# 12           Dog  Neutered Male        4 years
# 13           Dog  Neutered Male        2 years
# 14           Dog  Neutered Male         1 year
# 15           Cat  Neutered Male       3 months
# 16           Cat    Intact Male        3 weeks
# 17           Dog  Intact Female        2 weeks
# 18           Cat  Intact Female        2 years
# 19           Dog  Neutered Male         1 year
# 20           Dog    Intact Male       2 months
# 21           Cat  Spayed Female         1 year
# 22           Dog  Spayed Female        2 years
# 23           Dog  Neutered Male      10 months
# 24           Dog  Neutered Male       2 months
# 25           Cat  Intact Female        1 month
# 26           Dog  Spayed Female       6 months
# 27           Dog  Spayed Female        5 years
# 28           Cat  Spayed Female       2 months
# 29           Cat  Neutered Male        7 years
# ...          ...            ...            ...
# 26699        Dog  Neutered Male        2 years
# 26700        Dog    Intact Male      10 months
# 26701        Dog  Intact Female      11 months
# 26702        Cat  Spayed Female        2 years
# 26703        Cat  Neutered Male        6 years
# 26704        Cat  Intact Female        4 weeks
# 26705        Cat  Intact Female       2 months
# 26706        Cat  Spayed Female       2 months
# 26707        Cat        Unknown         1 year
# 26708        Dog  Neutered Male        2 years
# 26709        Dog  Spayed Female        1 month
# 26710        Dog  Intact Female        1 month
# 26711        Dog  Intact Female         1 year
# 26712        Dog  Neutered Male       12 years
# 26713        Cat  Intact Female       18 years
# 26714        Cat  Spayed Female       2 months
# 26715        Dog  Spayed Female       2 months
# 26716        Dog  Neutered Male       2 months
# 26717        Dog  Spayed Female        9 years
# 26718        Dog  Neutered Male       2 months
# 26719        Cat        Unknown        2 years
# 26720        Cat  Spayed Female       2 months
# 26721        Cat  Spayed Female        5 years
# 26722        Cat    Intact Male       5 months
# 26723        Dog  Neutered Male        6 years
# 26724        Cat    Intact Male        1 month
# 26725        Cat  Spayed Female       3 months
# 26726        Dog  Neutered Male        4 years
# 26727        Cat    Intact Male        4 weeks
# 26728        Cat    Intact Male         1 year
#
#                                        Breed                Color     Sex  \
# 0                      Shetland Sheepdog Mix          Brown/White    Male
# 1                     Domestic Shorthair Mix          Cream Tabby  Female
# 2                               Pit Bull Mix           Blue/White    Male
# 3                     Domestic Shorthair Mix           Blue Cream    Male
# 4                Lhasa Apso/Miniature Poodle                  Tan    Male
# 5          Cairn Terrier/Chihuahua Shorthair            Black/Tan  Female
# 6                     Domestic Shorthair Mix           Blue Tabby    Male
# 7                     Domestic Shorthair Mix          Brown Tabby  Female
# 8              American Pit Bull Terrier Mix            Red/White  Female
# 9                              Cairn Terrier                White  Female
# 10                    Domestic Shorthair Mix                Black  Female
# 11                   Miniature Schnauzer Mix               Silver  Female
# 12                              Pit Bull Mix                Brown    Male
# 13                     Yorkshire Terrier Mix            Black/Red    Male
# 14                        Great Pyrenees Mix          White/Cream    Male
# 15                    Domestic Shorthair Mix   Orange Tabby/White    Male
# 16                    Domestic Shorthair Mix          Brown Tabby    Male
# 17                              Pit Bull Mix          Brown/White  Female
# 18                                Angora Mix                White  Female
# 19                   Flat Coat Retriever Mix                Black    Male
# 20                     Queensland Heeler Mix          Black/White    Male
# 21                    Domestic Shorthair Mix                White  Female
# 22                         Plott Hound/Boxer  Brown Brindle/White  Female
# 23                       German Shepherd Mix          Brown/White    Male
# 24                       German Shepherd Mix          Black/Brown    Male
# 25                    Domestic Shorthair Mix         Orange Tabby  Female
# 26        American Staffordshire Terrier Mix      Chocolate/White  Female
# 27                   Chihuahua Shorthair Mix            White/Tan  Female
# 28                    Domestic Shorthair Mix    Cream Tabby/White  Female
# 29                          Russian Blue Mix                 Blue    Male
# ...                                      ...                  ...     ...
# 26699          American Pit Bull Terrier Mix          White/Black    Male
# 26700         Great Pyrenees/Anatol Shepherd            Tan/Cream    Male
# 26701               Jack Russell Terrier Mix          White/Black  Female
# 26702                            Siamese Mix           Lynx Point  Female
# 26703                  Domestic Longhair Mix           Seal Point    Male
# 26704                 Domestic Shorthair Mix          White/Black  Female
# 26705                 Domestic Shorthair Mix               Tortie  Female
# 26706                 Domestic Shorthair Mix                Black  Female
# 26707                 Domestic Shorthair Mix          Brown Tabby  Female
# 26708                Chihuahua Shorthair Mix          White/Brown    Male
# 26709                Chihuahua Shorthair Mix           Sable/Buff  Female
# 26710  Chihuahua Shorthair/Yorkshire Terrier          Brown/Black  Female
# 26711               Cocker Spaniel/Dachshund                 Buff  Female
# 26712                            Rat Terrier        Chocolate/Tan    Male
# 26713                  Domestic Longhair Mix               Tortie  Female
# 26714                 Domestic Shorthair Mix         Orange Tabby  Female
# 26715                            Pointer Mix          Black/White  Female
# 26716                       Newfoundland Mix          White/Black    Male
# 26717                        Bullmastiff Mix                Black  Female
# 26718         Siberian Husky/German Shepherd       Black/Tricolor    Male
# 26719                 Domestic Shorthair Mix    Brown Tabby/White  Female
# 26720                 Domestic Shorthair Mix          Brown Tabby  Female
# 26721                 Domestic Shorthair Mix                Black  Female
# 26722                 Domestic Shorthair Mix         Orange Tabby    Male
# 26723                      Staffordshire Mix           Blue/White    Male
# 26724                 Domestic Shorthair Mix    Brown Tabby/White    Male
# 26725                 Domestic Shorthair Mix          Brown Tabby  Female
# 26726                Old English Bulldog Mix            White/Tan    Male
# 26727                 Domestic Shorthair Mix                Black    Male
# 26728                 Domestic Shorthair Mix    Brown Tabby/White    Male
#
#        Neutered  AgeInYears  AgeCategory         Mix BreedGroup NameExsist
# 0      Neutered         1.0  young adult         Mix    Herding        Yes
# 1      Neutered         1.0  young adult         Mix   Domestic        Yes
# 2      Neutered         2.0  young adult         Mix     Fierce        Yes
# 3        Intact         0.1         baby         Mix   Domestic         No
# 4      Neutered         2.0  young adult         Mix  Companion         No
# 5        Intact         0.5         cubs         Mix    Hunting        Yes
# 6        Intact         0.1         baby         Mix   Domestic        Yes
# 7        Intact         0.1         baby         Mix   Domestic         No
# 8      Neutered         0.5         cubs         Mix     Fierce        Yes
# 9      Neutered         1.0  young adult  Pure Breed    Hunting         No
# 10       Intact         2.0  young adult         Mix   Domestic         No
# 11     Neutered         2.0  young adult         Mix        Toy         No
# 12     Neutered         4.0  young adult         Mix     Fierce        Yes
# 13     Neutered         2.0  young adult         Mix        Toy        Yes
# 14     Neutered         1.0  young adult         Mix    Working        Yes
# 15     Neutered         0.5         cubs         Mix   Domestic        Yes
# 16       Intact         0.1         baby         Mix   Domestic         No
# 17       Intact         0.1         baby         Mix     Fierce         No
# 18       Intact         2.0  young adult         Mix     Exotic        Yes
# 19     Neutered         1.0  young adult         Mix   Sporting        Yes
# 20       Intact         0.5         cubs         Mix    Herding        Yes
# 21     Neutered         1.0  young adult         Mix   Domestic        Yes
# 22     Neutered         2.0  young adult         Mix    Hunting        Yes
# 23     Neutered         1.0  young adult         Mix    Working        Yes
# 24     Neutered         0.5         cubs         Mix    Working        Yes
# 25       Intact         0.5         cubs         Mix   Domestic        Yes
# 26     Neutered         0.5         cubs         Mix    Hunting        Yes
# 27     Neutered         5.0        adult         Mix        Toy        Yes
# 28     Neutered         0.5         cubs         Mix   Domestic        Yes
# 29     Neutered         7.0        adult         Mix     Exotic        Yes
# ...         ...         ...          ...         ...        ...        ...
# 26699  Neutered         2.0  young adult         Mix     Fierce        Yes
# 26700    Intact         1.0  young adult         Mix    Working        Yes
# 26701    Intact         1.0  young adult         Mix    Hunting        Yes
# 26702  Neutered         2.0  young adult         Mix     Exotic         No
# 26703  Neutered         6.0        adult         Mix   Domestic        Yes
# 26704    Intact         0.1         baby         Mix   Domestic        Yes
# 26705    Intact         0.5         cubs         Mix   Domestic        Yes
# 26706  Neutered         0.5         cubs         Mix   Domestic        Yes
# 26707    Intact         1.0  young adult         Mix   Domestic         No
# 26708  Neutered         2.0  young adult         Mix        Toy        Yes
# 26709  Neutered         0.5         cubs         Mix        Toy         No
# 26710    Intact         0.5         cubs         Mix        Toy        Yes
# 26711    Intact         1.0  young adult         Mix   Sporting        Yes
# 26712  Neutered        12.0          old  Pure Breed    Hunting        Yes
# 26713    Intact        18.0          old         Mix   Domestic         No
# 26714  Neutered         0.5         cubs         Mix   Domestic        Yes
# 26715  Neutered         0.5         cubs         Mix   Sporting        Yes
# 26716  Neutered         0.5         cubs         Mix    Working        Yes
# 26717  Neutered         9.0        adult         Mix    Working        Yes
# 26718  Neutered         0.5         cubs         Mix    Working         No
# 26719    Intact         2.0  young adult         Mix   Domestic         No
# 26720  Neutered         0.5         cubs         Mix   Domestic        Yes
# 26721  Neutered         5.0        adult         Mix   Domestic        Yes
# 26722    Intact         0.5         cubs         Mix   Domestic         No
# 26723  Neutered         6.0        adult         Mix    Hunting        Yes
# 26724    Intact         0.5         cubs         Mix   Domestic         No
# 26725  Neutered         0.5         cubs         Mix   Domestic         No
# 26726  Neutered         4.0  young adult         Mix  Companion        Yes
# 26727    Intact         0.1         baby         Mix   Domestic         No
# 26728    Intact         1.0  young adult         Mix   Domestic         No
#
# [26729 rows x 17 columns]

# %%
from sklearn.preprocessing import LabelEncoder
dfX['NameExsist'] = LabelEncoder().fit_transform(dfX['NameExsist'])
dfX['DateTime'] = LabelEncoder().fit_transform(dfX['DateTime'])
dfX['AnimalType'] = LabelEncoder().fit_transform(dfX["AnimalType"])
dfX['Sex'] = LabelEncoder().fit_transform(dfX["Sex"])
dfX['Neutered'] = LabelEncoder().fit_transform(dfX['Neutered'])
dfX['AgeInYears'] = LabelEncoder().fit_transform(dfX['AgeInYears'])
dfX["Breed"] = LabelEncoder().fit_transform(dfX["Breed"])
dfX['Mix'] = LabelEncoder().fit_transform(dfX['Mix'])
dfX['Color'] = LabelEncoder().fit_transform(dfX['Color'])
dfX["BreedGroup"] = LabelEncoder().fit_transform(dfX["BreedGroup"])
dfX["OutcomeType"] = LabelEncoder().fit_transform(dfX["OutcomeType"])
dfX.head()

#dfX[['NameExsist', 'DateTime','AnimalType', 'Color','Sex', 'Neutered', 'AgeInYears','Mix', 'BreedGroup']]
# Out:
#   AnimalID     Name  DateTime  OutcomeType OutcomeSubtype  AnimalType  \
# 0  A671945  Hambone      3361            3            NaN           1
# 1  A656520    Emily       350            2      Suffering           0
# 2  A686464   Pearce     12680            0         Foster           1
# 3  A683430      NaN      7187            4        Partner           0
# 4  A667013      NaN      1233            4        Partner           1
#
#   SexuponOutcome AgeuponOutcome  Breed  Color  Sex  Neutered  AgeInYears  \
# 0  Neutered Male         1 year   1221    130    1         1           2
# 1  Spayed Female         1 year    640    167    0         1           2
# 2  Neutered Male        2 years   1066     86    1         1           3
# 3    Intact Male        3 weeks    640     42    1         0           0
# 4  Neutered Male        2 years    914    274    1         1           3
#
#    AgeCategory  Mix  BreedGroup  NameExsist
# 0  young adult    0           4           1
# 1  young adult    0           1           1
# 2  young adult    0           3           1
# 3         baby    0           1           0
# 4  young adult    0           0           0

# %% [markdown]
# ## Feature Selection

# %%
dfX
# Out:
#       AnimalID        Name  DateTime  OutcomeType OutcomeSubtype  AnimalType  \
# 0      A671945     Hambone      3361            3            NaN           1
# 1      A656520       Emily       350            2      Suffering           0
# 2      A686464      Pearce     12680            0         Foster           1
# 3      A683430         NaN      7187            4        Partner           0
# 4      A667013         NaN      1233            4        Partner           1
# 5      A677334        Elsa      5020            4        Partner           1
# 6      A699218       Jimmy     13870            4        Partner           0
# 7      A701489         NaN     14616            4        Partner           0
# 8      A671784        Lucy      3213            0            NaN           1
# 9      A677747         NaN      5228            0        Offsite           1
# 10     A668402         NaN      1712            4           SCRP           0
# 11     A666320         NaN       965            0            NaN           1
# 12     A684601      Rocket     22480            0         Foster           1
# 13     A704702     Scooter     15799            3            NaN           1
# 14     A688584     Preston     20766            3            NaN           1
# 15     A678825      Oliver      7206            0         Foster           0
# 16     A678050         NaN      5219            4        Partner           0
# 17     A680028         NaN      6132            4        Partner           1
# 18     A679010     Chrissy      5552            4        Partner           0
# 19     A684787        Kuma      7894            3            NaN           1
# 20     A670658      Anders      2857            4        Partner           1
# 21     A708812    Munchkin     18970            4        Partner           0
# 22     A705262     Jamaica     17960            0            NaN           1
# 23     A665781     Quattro       787            0            NaN           1
# 24     A676333     Trigger      4644            3            NaN           1
# 25     A712750       Olive     19329            4        Partner           0
# 26     A718832         Nia     22059            0            NaN           1
# 27     A698777       Chloe     13816            0            NaN           1
# 28     A715348     Cymbale     20654            0            NaN           0
# 29     A708666         Jax     17533            3            NaN           0
# ...        ...         ...       ...          ...            ...         ...
# 26699  A676460       Mario      4941            2       Behavior           1
# 26700  A704999        Lion     16006            3            NaN           1
# 26701  A678842        Ella      6369            4        Partner           1
# 26702  A713637         NaN     19562            1      In Kennel           0
# 26703  A716670      Mowmow     20991            4        Partner           0
# 26704  A716223       Alice     20570            4        Partner           0
# 26705  A662498       Grace       543            4        Partner           0
# 26706  A689942        Zoey     10150            0            NaN           0
# 26707  A682690         NaN      6863            2      Suffering           0
# 26708  A666920      Herbie      1207            4        Partner           1
# 26709  A714386         NaN     19904            0            NaN           1
# 26710  A692622      Bonnie     11033            4        Partner           1
# 26711  A666284       Sonja       843            4        Partner           1
# 26712  A535277      Merlin     14367            3            NaN           1
# 26713  A671169         NaN      2896            2      Suffering           0
# 26714  A679031        Pete      5945            0            NaN           0
# 26715  A708833        Luna     17701            0            NaN           1
# 26716  A697158         Max     14669            0        Offsite           1
# 26717  A519949       Bella      6834            3            NaN           1
# 26718  A701044         NaN     14569            0            NaN           1
# 26719  A707871         NaN     17268            4           SCRP           0
# 26720  A704405     Brownie     17096            0            NaN           0
# 26721  A662019  Green Bean      7480            0         Foster           0
# 26722  A687056         NaN      8838            4           SCRP           0
# 26723  A716997        Zeus     22400            0            NaN           1
# 26724  A702446         NaN     14981            4        Partner           0
# 26725  A718934         NaN     22209            4           SCRP           0
# 26726  A698128        Zeus     13462            0            NaN           1
# 26727  A677478         NaN      5074            4        Partner           0
# 26728  A706629         NaN     16643            4           SCRP           0
#
#       SexuponOutcome AgeuponOutcome  Breed  Color  Sex  Neutered  AgeInYears  \
# 0      Neutered Male         1 year   1221    130    1         1           2
# 1      Spayed Female         1 year    640    167    0         1           2
# 2      Neutered Male        2 years   1066     86    1         1           3
# 3        Intact Male        3 weeks    640     42    1         0           0
# 4      Neutered Male        2 years    914    274    1         1           3
# 5      Intact Female        1 month    369     36    0         0           1
# 6        Intact Male        3 weeks    640     63    1         0           0
# 7            Unknown        3 weeks    640    104    0         0           0
# 8      Spayed Female       5 months     45    250    0         1           1
# 9      Spayed Female         1 year    364    318    0         1           2
# 10           Unknown        2 years    640      5    0         0           3
# 11     Spayed Female        2 years    980    263    0         1           3
# 12     Neutered Male        4 years   1066     88    1         1           5
# 13     Neutered Male        2 years   1365     33    1         1           3
# 14     Neutered Male         1 year    764    338    1         1           2
# 15     Neutered Male       3 months    640    220    1         1           1
# 16       Intact Male        3 weeks    640    104    1         0           0
# 17     Intact Female        2 weeks   1066    130    0         0           0
# 18     Intact Female        2 years     72    318    0         0           3
# 19     Neutered Male         1 year    681      5    1         1           2
# 20       Intact Male       2 months   1158     38    1         0           1
# 21     Spayed Female         1 year    640    318    0         1           2
# 22     Spayed Female        2 years   1109     98    0         1           3
# 23     Neutered Male      10 months    696    130    1         1           2
# 24     Neutered Male       2 months    696     25    1         1           1
# 25     Intact Female        1 month    640    216    0         0           1
# 26     Spayed Female       6 months     55    165    0         1           1
# 27     Spayed Female        5 years    450    353    0         1           6
# 28     Spayed Female       2 months    640    168    0         1           1
# 29     Neutered Male        7 years   1207     41    1         1           8
# ...              ...            ...    ...    ...  ...       ...         ...
# 26699  Neutered Male        2 years     45    320    1         1           3
# 26700    Intact Male      10 months    765    282    1         0           2
# 26701  Intact Female      11 months    811    320    0         0           2
# 26702  Spayed Female        2 years   1251    211    0         1           3
# 26703  Neutered Male        6 years    632    260    1         1           7
# 26704  Intact Female        4 weeks    640    320    0         0           0
# 26705  Intact Female       2 months    640    296    0         0           1
# 26706  Spayed Female       2 months    640      5    0         1           1
# 26707        Unknown         1 year    640    104    0         0           2
# 26708  Neutered Male        2 years    450    329    1         1           3
# 26709  Spayed Female        1 month    450    255    0         1           1
# 26710  Intact Female        1 month    490    114    0         0           1
# 26711  Intact Female         1 year    522    131    0         0           2
# 26712  Neutered Male       12 years   1169    163    1         1          13
# 26713  Intact Female       18 years    632    296    0         0          19
# 26714  Spayed Female       2 months    640    216    0         1           1
# 26715  Spayed Female       2 months   1116     38    0         1           1
# 26716  Neutered Male       2 months    998    320    1         1           1
# 26717  Spayed Female        9 years    361      5    0         1          10
# 26718  Neutered Male       2 months   1262     37    1         1           1
# 26719        Unknown        2 years    640    111    0         0           3
# 26720  Spayed Female       2 months    640    104    0         1           1
# 26721  Spayed Female        5 years    640      5    0         1           6
# 26722    Intact Male       5 months    640    216    1         0           1
# 26723  Neutered Male        6 years   1291     86    1         1           7
# 26724    Intact Male        1 month    640    111    1         0           1
# 26725  Spayed Female       3 months    640    104    0         1           1
# 26726  Neutered Male        4 years   1022    353    1         1           5
# 26727    Intact Male        4 weeks    640      5    1         0           0
# 26728    Intact Male         1 year    640    111    1         0           2
#
#        AgeCategory  Mix  BreedGroup  NameExsist
# 0      young adult    0           4           1
# 1      young adult    0           1           1
# 2      young adult    0           3           1
# 3             baby    0           1           0
# 4      young adult    0           0           0
# 5             cubs    0           5           1
# 6             baby    0           1           1
# 7             baby    0           1           0
# 8             cubs    0           3           1
# 9      young adult    1           5           0
# 10     young adult    0           1           0
# 11     young adult    0           7           0
# 12     young adult    0           3           1
# 13     young adult    0           7           1
# 14     young adult    0           8           1
# 15            cubs    0           1           1
# 16            baby    0           1           0
# 17            baby    0           3           0
# 18     young adult    0           2           1
# 19     young adult    0           6           1
# 20            cubs    0           4           1
# 21     young adult    0           1           1
# 22     young adult    0           5           1
# 23     young adult    0           8           1
# 24            cubs    0           8           1
# 25            cubs    0           1           1
# 26            cubs    0           5           1
# 27           adult    0           7           1
# 28            cubs    0           1           1
# 29           adult    0           2           1
# ...            ...  ...         ...         ...
# 26699  young adult    0           3           1
# 26700  young adult    0           8           1
# 26701  young adult    0           5           1
# 26702  young adult    0           2           0
# 26703        adult    0           1           1
# 26704         baby    0           1           1
# 26705         cubs    0           1           1
# 26706         cubs    0           1           1
# 26707  young adult    0           1           0
# 26708  young adult    0           7           1
# 26709         cubs    0           7           0
# 26710         cubs    0           7           1
# 26711  young adult    0           6           1
# 26712          old    1           5           1
# 26713          old    0           1           0
# 26714         cubs    0           1           1
# 26715         cubs    0           6           1
# 26716         cubs    0           8           1
# 26717        adult    0           8           1
# 26718         cubs    0           8           0
# 26719  young adult    0           1           0
# 26720         cubs    0           1           1
# 26721        adult    0           1           1
# 26722         cubs    0           1           0
# 26723        adult    0           5           1
# 26724         cubs    0           1           0
# 26725         cubs    0           1           0
# 26726  young adult    0           0           1
# 26727         baby    0           1           0
# 26728  young adult    0           1           0
#
# [26729 rows x 17 columns]

# %%
## 독립변수 X 와 종속 변수 y 분류 

## Animal ID 제거: key 값 
## OutcomeSubType 제거: test 파일에는 OutcomeSubType feature 없음
## sexuponoutcome 은 Sex와 Neutered feature로 대체
## Mix type 추가 (필요없을시 삭제 예정)
## AgeuponOutcome 은 AgeInYears로 대체 
## AgeCategory는 AgeInYears를 바탕으로 만들었으므로 상관성 높음: 삭제 
## Breed는 Breed Group으로 대체 

X = dfX[['NameExsist', 'DateTime','AnimalType', 'Color',
       'Sex', 'Neutered', 'AgeInYears','Mix', 'BreedGroup','Breed']]
y = dfX['OutcomeType']

# %%
## 랜덤포레스트를 통한 feature Importance 구하기 
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier ## 랜덤포레스트

forest = ExtraTreesClassifier(n_estimators=250, random_state=0)
forest.fit(X, y)

importances = forest.feature_importances_

std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

print("Feature ranking:")
for f in range(X.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()

#dfX[['NameExsist', 'DateTime','AnimalType', 'Color','Sex', 'Neutered', 'AgeInYears','Mix', 'BreedGroup',''Breed']]
# Out:
# Feature ranking:
# 1. feature 1 (0.313876)
# 2. feature 3 (0.158538)
# 3. feature 5 (0.147297)
# 4. feature 6 (0.147144)
# 5. feature 9 (0.102704)
# 6. feature 0 (0.047242)
# 7. feature 8 (0.043452)
# 8. feature 2 (0.023243)
# 9. feature 4 (0.010149)
# 10. feature 7 (0.006354)

# %%
## Lasso 회귀 Feature Importance 구하기 

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
alpha = np.logspace(-3, 1, 5)

data = []
for i, a in enumerate(alpha):
    lasso = Lasso(alpha=a).fit(X, y)
    data.append(pd.Series(np.hstack([lasso.intercept_, lasso.coef_])))
    
df_lasso = pd.DataFrame(data, index=alpha).T
df_lasso
# Out:
#       0.001     0.010     0.100     1.000     10.000
# 0   3.275275  3.244860  2.965720  2.110993  2.156451
# 1  -0.309133 -0.255217 -0.000000 -0.000000 -0.000000
# 2  -0.000004 -0.000004 -0.000006 -0.000008 -0.000008
# 3   0.196024  0.053471 -0.000000 -0.000000 -0.000000
# 4   0.000155  0.000170  0.000087 -0.000155 -0.000000
# 5   0.064143  0.028614  0.000000 -0.000000 -0.000000
# 6  -1.962673 -1.927454 -1.564156 -0.000000 -0.000000
# 7   0.091129  0.090283  0.061488  0.000000  0.000000
# 8   0.177946  0.000000  0.000000  0.000000  0.000000
# 9  -0.020956 -0.000000 -0.000000 -0.000000 -0.000000
# 10  0.000069  0.000077  0.000086  0.000113  0.000007

# %%
mpl.rcParams["font.family"] = 'DejaVu Sans'


plt.semilogx(df_lasso.T)
plt.xticks(alpha)
plt.title("Lasso")
plt.show() ##여기서는 Breed 보다 BreedGroup이 성능이 더 좋음, 나머지는 의사결정나무와 같은 결과

# %%
## XGBoost 사용

import xgboost
model_xgb = xgboost.XGBClassifier(n_estimators=100, max_depth=2)
# %time
model_xgb.fit(X, y)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Wall time: 0 ns
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=2,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %% [markdown]
# ## 교차검증을 통한 negative log loss 성능비교

# %% [markdown]
# ### Random Forest

# %%
## 비교평가 기준 = negative log loss 

X = dfX[['NameExsist','AnimalType',
       'Neutered', 'Sex']]
y = dfX['OutcomeType']

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
cv = KFold(20)

forest = ExtraTreesClassifier(n_estimators= 5)
#xgb = xgboost.XGBClassifier(n_estimators=100, max_depth=2)

print(cross_val_score(forest, X, y, scoring="neg_log_loss", cv=cv)*-1)
print(cross_val_score(forest, X, y, scoring="neg_log_loss", cv=cv).mean()*-1)
print(cross_val_score(forest, X, y, scoring="neg_log_loss", cv=cv).std())
## Datetime과 color 삭제안한경우 7.38958494946
## Datetime과 color 삭제한경우 ## 1.90113679581
## 참고: 추가로 Sex 와 Mix , AgeInYears 삭제한경우 성능 더 좋아짐 forest n_estimators = 5또는 100인경우  0.955949165544
## ['NameExsist','AnimalType','Mix','AgeInYears','Neutered', 'BreedGroup'] 1.47327458396
##['NameExsist','AnimalType','AgeInYears','Neutered', 'BreedGroup'] 1.27438821504
##['NameExsist','AnimalType','Neutered', 'BreedGroup'] 0.95949751197
## ['NameExsist','AnimalType','Neutered', 'Sex'] 0.955856312519
## forest n_estimators = 150으로 높이면 오히려 성능 안좋아짐
## feature 순서에 따라 점수가 변경되는거 같음
# Out:
# [ 0.95726693  0.93676361  0.94648555  0.95835157  0.99365819  0.98576299
#   0.92988745  0.9728357   0.93296812  0.93577921  0.96973888  0.95056024
#   0.97069473  1.00448405  0.94226654  0.92928837  0.93275728  0.9723535
#   0.92459723  0.97062614]
# 0.955856312519
# 0.0227714056744

# %%
## 비교평가 기준 = accuracy

X = dfX[['DateTime','NameExsist','AnimalType','Mix','AgeInYears',
       'Neutered', 'BreedGroup']]
y = dfX['OutcomeType']


from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
cv = KFold(20)

forest = ExtraTreesClassifier(n_estimators=5)
#xgb = xgboost.XGBClassifier(n_estimators=100, max_depth=2)

print(cross_val_score(forest, X, y, scoring="accuracy", cv=cv))
print(cross_val_score(forest, X, y, scoring="accuracy", cv=cv).mean()) 
# print(cross_val_score(forest, X, y, scoring="accyracy", cv=cv).std())
## Datetime과 Color 삭제 안한경우 0.58408454221
## Datetime과 Color 삭제 한경우 0.618878734677
# Out:
# [ 0.60807779  0.61854899  0.6013463   0.58040389  0.58189978  0.59910247
#   0.61106956  0.59685864  0.58040389  0.61751497  0.59580838  0.57934132
#   0.58607784  0.61601796  0.61526946  0.5995509   0.62649701  0.61751497
#   0.61826347  0.59505988]
# 0.601969564984

# %% [markdown]
# ### XGBoost

# %%
## 비교평가 기준 = negative log loss 


X = dfX[['DateTime','NameExsist','AnimalType','Mix','AgeInYears',
       'Neutered', 'BreedGroup']]
y = dfX['OutcomeType']


from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
cv = KFold(20)

#forest = ExtraTreesClassifier(n_estimators=5)
xgb = xgboost.XGBClassifier(n_estimators=200, max_depth=7)

print(cross_val_score(xgb, X, y, scoring="neg_log_loss", cv=cv)*-1)
print(cross_val_score(xgb, X, y, scoring="neg_log_loss", cv=cv).mean()*-1)
# print(cross_val_score(xgb, X, y, scoring="neg_log_loss", cv=cv).std())
## ['DateTime','Color','Sex',NameExsist','AnimalType','Mix','AgeInYears','Neutered', 'BreedGroup']  ##0.863882821646 
## ['DateTime','NameExsist','AnimalType','Mix','AgeInYears','Neutered', 'BreedGroup'] ## 0.865272014676
## 추가로 AgeInYears 삭제한경우 성능 나빠짐 0.952535292702
##  n_estimators=100,max_depth = 5 인경우 0.832896443612
##  n_estimators=100,max_depth = 7 인경우 0.824533291808
##  n_estimators=100, max_depth = 10 인경우 0.821044977464
##  n_estimators=150,max_depth = 7 인경우 0.818981567625
##  n_estimators=200,max_depth = 7 인경우 0.813925463379
## n_estimators=200, max_depth=10 인경우 0.815273286334
## n_estimators=250, max_depth=7 인경우 0.815273286334
## ['NameExsist','AnimalType','Neutered', 'Sex'], 200, 7 인경우 0.952856248738
## DateTime 정제 하고 확인 필요
# Out:
# [ 0.95727051  0.93676278  0.94649367  0.95833965  0.9936464   0.96540843
#   0.92987253  0.97283419  0.93296425  0.93575607  0.96974754  0.9505653
#   0.97067286  0.96490829  0.94227608  0.92928811  0.93275634  0.97234356
#   0.924589    0.97062941]
# 0.952856248738

# %%
## 비교평가 기준 = accuracy

X = dfX[['DateTime','NameExsist','AnimalType','Mix','AgeInYears',
       'Neutered', 'BreedGroup']]
y = dfX['OutcomeType']


from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
cv = KFold(20)

#forest = ExtraTreesClassifier(n_estimators=5)
xgb = xgboost.XGBClassifier(n_estimators=100, max_depth=2)

print(cross_val_score(xgb, X, y, scoring="accuracy", cv=cv))
print(cross_val_score(xgb, X, y, scoring="accuracy", cv=cv).mean()) 
# print(cross_val_score(forest, X, y, scoring="accyracy", cv=cv).std())
## Datetime과 Color 삭제 안한경우 0.64371954483
## Datetime과 Color 삭제 한경우 0.643981464894
# Out:
# [ 0.64697083  0.64846672  0.64397906  0.64323111  0.63575168  0.63500374
#   0.644727    0.63874346  0.66641735  0.65494012  0.63398204  0.63323353
#   0.63323353  0.62350299  0.64595808  0.64146707  0.65269461  0.6511976
#   0.65419162  0.63398204]
# 0.643083709171
